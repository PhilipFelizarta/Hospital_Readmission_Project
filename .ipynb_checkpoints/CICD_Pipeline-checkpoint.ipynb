# %%
# !pip install papermill
# Out:
# Requirement already satisfied: papermill in /opt/conda/lib/python3.11/site-packages (2.6.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from papermill) (8.1.8)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from papermill) (6.0.2)
# Requirement already satisfied: nbformat>=5.2.0 in /opt/conda/lib/python3.11/site-packages (from papermill) (5.10.4)
# Requirement already satisfied: nbclient>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from papermill) (0.10.2)
# Requirement already satisfied: tqdm>=4.32.2 in /opt/conda/lib/python3.11/site-packages (from papermill) (4.67.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from papermill) (2.32.3)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.11/site-packages (from papermill) (0.4)
# Requirement already satisfied: tenacity>=5.0.2 in /opt/conda/lib/python3.11/site-packages (from papermill) (9.0.0)
# Requirement already satisfied: ansicolors in /opt/conda/lib/python3.11/site-packages (from papermill) (1.1.8)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.11/site-packages (from nbclient>=0.2.0->papermill) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.11/site-packages (from nbclient>=0.2.0->papermill) (5.7.2)
# Requirement already satisfied: traitlets>=5.4 in /opt/conda/lib/python3.11/site-packages (from nbclient>=0.2.0->papermill) (5.14.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/conda/lib/python3.11/site-packages (from nbformat>=5.2.0->papermill) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.11/site-packages (from nbformat>=5.2.0->papermill) (4.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->papermill) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->papermill) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->papermill) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->papermill) (2024.12.14)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.2.0->papermill) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.2.0->papermill) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.2.0->papermill) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.2.0->papermill) (0.22.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.2.0->papermill) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.2.0->papermill) (26.2.1)
# Requirement already satisfied: tornado>=6.2 in /opt/conda/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.2.0->papermill) (6.4.2)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->nbclient>=0.2.0->papermill) (4.3.6)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.2.0->papermill) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.11/site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat>=5.2.0->papermill) (4.12.2)

# %%
import papermill as pm
import networkx as nx
import matplotlib.pyplot as plt
import json

def run_cicd(config_dict):
    # Save configuration to JSON file
    with open("pipeline_config.json", "w") as json_file:
        json.dump(config_dict, json_file, indent=4)

    # Define Jupyter notebooks and DAG nodes
    notebooks = {
        "Init_Data.ipynb": "Get Labeled Data",
        "Setup_Feature_Store.ipynb": "Data Preprocessing",
        "Train_XGB.ipynb": "Model Training & Store",
        "Deployment_Monitoring.ipynb": "Model Deployment and Monitoring",
    }

    # Define DAG structure
    dag = nx.DiGraph()
    dag.add_edges_from([
        ("Get Labeled Data", "Data Preprocessing"),
        ("Data Preprocessing", "Model Training & Store"),
        ("Model Training & Store", "Model Deployment and Monitoring")
    ])

    # Track execution results
    execution_results = {}

    def execute_notebook(notebook_path, node_name):
        """Executes a Jupyter notebook and updates DAG if it fails."""
        try:
            pm.execute_notebook(
                notebook_path,
                f"executed_{notebook_path}",  # Save output notebook
                log_output=True
            )
            execution_results[node_name] = "success"
            return True
        except Exception as e:
            execution_results[node_name] = "failed"
            print(f"Notebook {notebook_path} failed: {e}")

            # Mark failure in DAG
            dag.nodes[node_name]["color"] = "red"

            # Add failure edge ONLY if the node fails
            failure_edges = {
                "Data Preprocessing": "Preprocessing Failed",
                "Model Training & Store": "Training Failed",
                "Model Deployment and Monitoring": "Deployment Failed"
            }
            
            if node_name in failure_edges:
                failure_node = failure_edges[node_name]
                dag.add_edge(node_name, failure_node)
                dag.nodes[failure_node]["color"] = "red"

            # Save execution results
            save_results()

            # Show failure visualization
            plot_dag(dag, "CI/CD Pipeline Status - FAILURE")

            # **Stop pipeline execution immediately**
            raise RuntimeError(f"Pipeline stopped due to failure in {node_name}")

    def save_results():
        """Save pipeline execution results to a JSON file."""
        with open("pipeline_results.json", "w") as result_file:
            json.dump(execution_results, result_file, indent=4)

    def plot_dag(dag, title="CI/CD Pipeline Status"):
        """Plots the DAG with failed nodes highlighted."""
        plt.figure(figsize=(10, 6))
        pos = nx.spring_layout(dag)

        # Determine node colors based on execution status
        node_colors = [
            "red" if dag.nodes.get(node, {}).get("color") == "red" else "lightblue"
            for node in dag.nodes
        ]

        nx.draw(dag, pos, with_labels=True, node_color=node_colors, edge_color="gray", node_size=3000, font_size=10)
        plt.title(title)
        plt.show()

    # Execute Notebooks in Order
    for notebook, node in notebooks.items():
        success = execute_notebook(notebook, node)
        if not success:
            break  # **Stop execution on failure**

    # Save final execution results
    save_results()

    # Show final pipeline status if all passed
    plot_dag(dag, "CI/CD Pipeline Status - SUCCESS")

# %%
fail_config = {
    "N_Trials": -1.23
}
run_cicd(fail_config)
# Out:
# Passed unknown parameter: N_Trials
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# /tmp/ipykernel_3272/3350967399.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#
# Passed unknown parameter: N_Trials
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]
# /tmp/ipykernel_3307/537684722.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
#
# /tmp/ipykernel_3307/4109648834.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_all_features = pd.read_sql(query, connection)
#
# Passed unknown parameter: N_Trials
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/26 [00:00<?, ?cell/s]
# /tmp/ipykernel_3380/530253379.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
#
# [I 2025-03-01 22:20:21,009] A new study created in memory with name: no-name-c6519f19-3c49-4152-8830-d68ab69e4b24
# ❌ Notebook Train_XGB.ipynb failed:
# ---------------------------------------------------------------------------
# Exception encountered at "In [13]":
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 26
#      23 study = optuna.create_study(direction="maximize")
#      24 study.optimize(xgb_objective, n_trials=N_TRIALS)
# ---> 26 best_params = study.best_params
#      27 best_params['max_depth'] = int(best_params['max_depth'])
#
# File /opt/conda/lib/python3.11/site-packages/optuna/study/study.py:119, in Study.best_params(self)
#     107 @property
#     108 def best_params(self) -> dict[str, Any]:
#     109     """Return parameters of the best trial in the study.
#     110
#     111     .. note::
#    (...)
#     116
#     117     """
# --> 119     return self.best_trial.params
#
# File /opt/conda/lib/python3.11/site-packages/optuna/study/study.py:162, in Study.best_trial(self)
#     156 if self._is_multi_objective():
#     157     raise RuntimeError(
#     158         "A single best trial cannot be retrieved from a multi-objective study. Consider "
#     159         "using Study.best_trials to retrieve a list containing the best trials."
#     160     )
# --> 162 best_trial = self._storage.get_best_trial(self._study_id)
#     164 # If the trial with the best value is infeasible, select the best trial from all feasible
#     165 # trials. Note that the behavior is undefined when constrained optimization without the
#     166 # violation value in the best-valued trial.
#     167 constraints = best_trial.system_attrs.get(_CONSTRAINTS_KEY)
#
# File /opt/conda/lib/python3.11/site-packages/optuna/storages/_in_memory.py:249, in InMemoryStorage.get_best_trial(self, study_id)
#     246 best_trial_id = self._studies[study_id].best_trial_id
#     248 if best_trial_id is None:
# --> 249     raise ValueError("No trials are completed yet.")
#     250 elif len(self._studies[study_id].directions) > 1:
#     251     raise RuntimeError(
#     252         "Best trial can be obtained only for single-objective optimization."
#     253     )
#
# ValueError: No trials are completed yet.
# /opt/conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 10060 (\N{CROSS MARK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ---------------------------------------------------------------------------
# PapermillExecutionError                   Traceback (most recent call last)
# Cell In[2], line 33, in run_cicd.<locals>.execute_notebook(notebook_path, node_name)
#      32 try:
# ---> 33     pm.execute_notebook(
#      34         notebook_path,
#      35         f"executed_{notebook_path}",  # Save output notebook
#      36         parameters=config_dict,  # Pass configuration dictionary
#      37         log_output=True
#      38     )
#      39     execution_results[node_name] = "success"
#
# File /opt/conda/lib/python3.11/site-packages/papermill/execute.py:131, in execute_notebook(input_path, output_path, parameters, engine_name, request_save_on_cell_execute, prepare_only, kernel_name, language, progress_bar, log_output, stdout_file, stderr_file, start_timeout, report_mode, cwd, **engine_kwargs)
#     130     # Check for errors first (it saves on error before raising)
# --> 131     raise_for_execution_errors(nb, output_path)
#     133 # Write final output in case the engine didn't write it on cell completion.
#
# File /opt/conda/lib/python3.11/site-packages/papermill/execute.py:251, in raise_for_execution_errors(nb, output_path)
#     250 write_ipynb(nb, output_path)
# --> 251 raise error
#
# PapermillExecutionError:
# ---------------------------------------------------------------------------
# Exception encountered at "In [13]":
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 26
#      23 study = optuna.create_study(direction="maximize")
#      24 study.optimize(xgb_objective, n_trials=N_TRIALS)
# ---> 26 best_params = study.best_params
#      27 best_params['max_depth'] = int(best_params['max_depth'])
#
# File /opt/conda/lib/python3.11/site-packages/optuna/study/study.py:119, in Study.best_params(self)
#     107 @property
#     108 def best_params(self) -> dict[str, Any]:
#     109     """Return parameters of the best trial in the study.
#     110
#     111     .. note::
#    (...)
#     116
#     117     """
# --> 119     return self.best_trial.params
#
# File /opt/conda/lib/python3.11/site-packages/optuna/study/study.py:162, in Study.best_trial(self)
#     156 if self._is_multi_objective():
#     157     raise RuntimeError(
#     158         "A single best trial cannot be retrieved from a multi-objective study. Consider "
#     159         "using Study.best_trials to retrieve a list containing the best trials."
#     160     )
# --> 162 best_trial = self._storage.get_best_trial(self._study_id)
#     164 # If the trial with the best value is infeasible, select the best trial from all feasible
#     165 # trials. Note that the behavior is undefined when constrained optimization without the
#     166 # violation value in the best-valued trial.
#     167 constraints = best_trial.system_attrs.get(_CONSTRAINTS_KEY)
#
# File /opt/conda/lib/python3.11/site-packages/optuna/storages/_in_memory.py:249, in InMemoryStorage.get_best_trial(self, study_id)
#     246 best_trial_id = self._studies[study_id].best_trial_id
#     248 if best_trial_id is None:
# --> 249     raise ValueError("No trials are completed yet.")
#     250 elif len(self._studies[study_id].directions) > 1:
#     251     raise RuntimeError(
#     252         "Best trial can be obtained only for single-objective optimization."
#     253     )
#
# ValueError: No trials are completed yet.
#
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 4
#       1 fail_config = {
#       2     "N_Trials": -1.23
#       3 }
# ----> 4 run_cicd(fail_config)
#
# Cell In[2], line 91, in run_cicd(config_dict)
#      89 # Execute Notebooks in Order
#      90 for notebook, node in notebooks.items():
# ---> 91     success = execute_notebook(notebook, node)
#      92     if not success:
#      93         break  # **Stop execution on failure**
#
# Cell In[2], line 67, in run_cicd.<locals>.execute_notebook(notebook_path, node_name)
#      64 plot_dag(dag, "CI/CD Pipeline Status - FAILURE ❌")
#      66 # **Stop pipeline execution immediately**
# ---> 67 raise RuntimeError(f"Pipeline stopped due to failure in {node_name}")
#
# RuntimeError: Pipeline stopped due to failure in Model Training & Store

# %%
success_config = {
    "N_Trials": int(2)
}
run_cicd(success_config)
# Out:
# Passed unknown parameter: N_Trials
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# /tmp/ipykernel_5142/3350967399.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#
# Passed unknown parameter: N_Trials
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]
# /tmp/ipykernel_5177/537684722.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
#
# /tmp/ipykernel_5177/4109648834.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_all_features = pd.read_sql(query, connection)
#
# Passed unknown parameter: N_Trials
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/26 [00:00<?, ?cell/s]
# /tmp/ipykernel_5256/530253379.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
#
# [I 2025-03-01 22:57:19,411] A new study created in memory with name: no-name-fb9b7163-40d8-4dc8-94e1-71ac0afe2452
#
# [I 2025-03-01 22:57:19,756] Trial 0 finished with value: 0.6138708247117942 and parameters: {'learning_rate': 0.2749806948047179, 'max_depth': 8, 'min_child_weight': 1.3947877015869985, 'colsample_bytree': 0.31651985989414844, 'subsample': 0.8820426243025863}. Best is trial 0 with value: 0.6138708247117942.
#
# [I 2025-03-01 22:57:20,071] Trial 1 finished with value: 0.6342994383683122 and parameters: {'learning_rate': 0.11946957908052601, 'max_depth': 8, 'min_child_weight': 8.740270785488025, 'colsample_bytree': 0.48014636018936707, 'subsample': 0.7331788864907206}. Best is trial 1 with value: 0.6342994383683122.
#
# [I 2025-03-01 22:57:20,351] Trial 2 finished with value: 0.635369494531481 and parameters: {'learning_rate': 0.14921494818110992, 'max_depth': 9, 'min_child_weight': 9.332911699501375, 'colsample_bytree': 0.40488105754701387, 'subsample': 0.9755940746803261}. Best is trial 2 with value: 0.635369494531481.
#
# [I 2025-03-01 22:57:20,647] Trial 3 finished with value: 0.6408793969849247 and parameters: {'learning_rate': 0.0756179910633022, 'max_depth': 10, 'min_child_weight': 6.694273536201421, 'colsample_bytree': 0.3911615754950535, 'subsample': 0.7359509398503743}. Best is trial 3 with value: 0.6408793969849247.
#
# [I 2025-03-01 22:57:21,050] Trial 4 finished with value: 0.639342299733964 and parameters: {'learning_rate': 0.0800801126121514, 'max_depth': 10, 'min_child_weight': 8.468911881319594, 'colsample_bytree': 0.6664087278108974, 'subsample': 0.9204942679045756}. Best is trial 3 with value: 0.6408793969849247.
#
# [I 2025-03-01 22:57:21,240] Trial 5 finished with value: 0.6363730416789832 and parameters: {'learning_rate': 0.11449002998609689, 'max_depth': 5, 'min_child_weight': 7.305180094187116, 'colsample_bytree': 0.840369010889719, 'subsample': 0.5301875010022774}. Best is trial 3 with value: 0.6408793969849247.
#
# [I 2025-03-01 22:57:21,491] Trial 6 finished with value: 0.619923145137452 and parameters: {'learning_rate': 0.15914858385907876, 'max_depth': 8, 'min_child_weight': 8.12919983440774, 'colsample_bytree': 0.7908436135454586, 'subsample': 0.7692069797534311}. Best is trial 3 with value: 0.6408793969849247.
#
# [I 2025-03-01 22:57:21,666] Trial 7 finished with value: 0.6331377475613361 and parameters: {'learning_rate': 0.16637464743523242, 'max_depth': 4, 'min_child_weight': 7.8712224541435685, 'colsample_bytree': 0.5880188839979781, 'subsample': 0.871332617700599}. Best is trial 3 with value: 0.6408793969849247.
#
# [I 2025-03-01 22:57:21,921] Trial 8 finished with value: 0.610659178244162 and parameters: {'learning_rate': 0.2971641254044598, 'max_depth': 9, 'min_child_weight': 9.184861174618595, 'colsample_bytree': 0.5303238486406243, 'subsample': 0.8857836582875993}. Best is trial 3 with value: 0.6408793969849247.
#
# [I 2025-03-01 22:57:22,167] Trial 9 finished with value: 0.6070610404966006 and parameters: {'learning_rate': 0.2664920915951849, 'max_depth': 9, 'min_child_weight': 6.5811738886349085, 'colsample_bytree': 0.30207752551220757, 'subsample': 0.8807579645974365}. Best is trial 3 with value: 0.6408793969849247.
#
# [I 2025-03-01 22:57:22,560] Trial 10 finished with value: 0.6407286432160805 and parameters: {'learning_rate': 0.01679691243118242, 'max_depth': 6, 'min_child_weight': 3.932119248472466, 'colsample_bytree': 0.9730514853281065, 'subsample': 0.6071849600287641}. Best is trial 3 with value: 0.6408793969849247.
#
# [I 2025-03-01 22:57:22,866] Trial 11 finished with value: 0.6426973100798108 and parameters: {'learning_rate': 0.019467149092566666, 'max_depth': 6, 'min_child_weight': 4.055437667124815, 'colsample_bytree': 0.9860834031559012, 'subsample': 0.6023462342700809}. Best is trial 11 with value: 0.6426973100798108.
#
# [I 2025-03-01 22:57:23,088] Trial 12 finished with value: 0.6306155778894472 and parameters: {'learning_rate': 0.011250681237339334, 'max_depth': 3, 'min_child_weight': 4.6533727765957265, 'colsample_bytree': 0.9835803838985664, 'subsample': 0.6765900327853552}. Best is trial 11 with value: 0.6426973100798108.
#
# [I 2025-03-01 22:57:23,374] Trial 13 finished with value: 0.639863287023352 and parameters: {'learning_rate': 0.056669601969402836, 'max_depth': 6, 'min_child_weight': 3.0513920019538294, 'colsample_bytree': 0.7198294884769894, 'subsample': 0.5136384807127748}. Best is trial 11 with value: 0.6426973100798108.
#
# [I 2025-03-01 22:57:23,656] Trial 14 finished with value: 0.6400073898906296 and parameters: {'learning_rate': 0.05999609254006407, 'max_depth': 7, 'min_child_weight': 5.843059667887136, 'colsample_bytree': 0.8776248126802841, 'subsample': 0.6356355306961171}. Best is trial 11 with value: 0.6426973100798108.
#
# [I 2025-03-01 22:57:23,873] Trial 15 finished with value: 0.6247177061779485 and parameters: {'learning_rate': 0.20036143735699208, 'max_depth': 5, 'min_child_weight': 2.742930046153562, 'colsample_bytree': 0.39912240500772833, 'subsample': 0.7680412004524039}. Best is trial 11 with value: 0.6426973100798108.
#
# [I 2025-03-01 22:57:24,141] Trial 16 finished with value: 0.6443260419745789 and parameters: {'learning_rate': 0.05334186283306787, 'max_depth': 7, 'min_child_weight': 5.186150770390886, 'colsample_bytree': 0.614513937076842, 'subsample': 0.5881948020877301}. Best is trial 16 with value: 0.6443260419745789.
#
# [I 2025-03-01 22:57:24,432] Trial 17 finished with value: 0.6448418563405263 and parameters: {'learning_rate': 0.03928848186859732, 'max_depth': 7, 'min_child_weight': 5.184687152415168, 'colsample_bytree': 0.7338830406233894, 'subsample': 0.580077043453867}. Best is trial 17 with value: 0.6448418563405263.
#
# [I 2025-03-01 22:57:24,696] Trial 18 finished with value: 0.6114026012415016 and parameters: {'learning_rate': 0.21419676915689817, 'max_depth': 7, 'min_child_weight': 5.678658377619447, 'colsample_bytree': 0.7221895834084039, 'subsample': 0.5573354838048902}. Best is trial 17 with value: 0.6448418563405263.
#
# [I 2025-03-01 22:57:25,014] Trial 19 finished with value: 0.643100798108188 and parameters: {'learning_rate': 0.10687750644316435, 'max_depth': 7, 'min_child_weight': 4.644082044709356, 'colsample_bytree': 0.6118190954638245, 'subsample': 0.673416099422321}. Best is trial 17 with value: 0.6448418563405263.
#
# [I 2025-03-01 22:57:25,282] Trial 20 finished with value: 0.6426603606266628 and parameters: {'learning_rate': 0.04277067750064277, 'max_depth': 5, 'min_child_weight': 2.0680080795427442, 'colsample_bytree': 0.6924160034599289, 'subsample': 0.5628029329478053}. Best is trial 17 with value: 0.6448418563405263.
#
# [I 2025-03-01 22:57:25,615] Trial 21 finished with value: 0.6370366538575228 and parameters: {'learning_rate': 0.10193207742356136, 'max_depth': 7, 'min_child_weight': 4.8517706393561415, 'colsample_bytree': 0.6020256626550812, 'subsample': 0.6647472641827702}. Best is trial 17 with value: 0.6448418563405263.
#
# [I 2025-03-01 22:57:25,942] Trial 22 finished with value: 0.6401330180313332 and parameters: {'learning_rate': 0.08777824874723592, 'max_depth': 7, 'min_child_weight': 5.048765733495195, 'colsample_bytree': 0.6164542725967747, 'subsample': 0.6860651708942397}. Best is trial 17 with value: 0.6448418563405263.
#
# [I 2025-03-01 22:57:26,472] Trial 23 finished with value: 0.643587052911617 and parameters: {'learning_rate': 0.05022007944192236, 'max_depth': 8, 'min_child_weight': 3.9777980515263582, 'colsample_bytree': 0.7660013353000981, 'subsample': 0.5889285092939341}. Best is trial 17 with value: 0.6448418563405263.
#
# [I 2025-03-01 22:57:26,979] Trial 24 finished with value: 0.6413715637008572 and parameters: {'learning_rate': 0.04555931744198927, 'max_depth': 8, 'min_child_weight': 3.299075830339876, 'colsample_bytree': 0.7658188895223856, 'subsample': 0.5912072587702042}. Best is trial 17 with value: 0.6448418563405263.
#
# [I 2025-03-01 22:57:27,466] Trial 25 finished with value: 0.6407315991723322 and parameters: {'learning_rate': 0.03711508599990174, 'max_depth': 8, 'min_child_weight': 6.359028191279945, 'colsample_bytree': 0.8866893720755975, 'subsample': 0.500868025088743}. Best is trial 17 with value: 0.6448418563405263.
#
# [I 2025-03-01 22:57:27,757] Trial 26 finished with value: 0.6354167898315105 and parameters: {'learning_rate': 0.1371447742023984, 'max_depth': 6, 'min_child_weight': 3.96496811536009, 'colsample_bytree': 0.788181987596612, 'subsample': 0.5567805791273408}. Best is trial 17 with value: 0.6448418563405263.
#
# [I 2025-03-01 22:57:28,165] Trial 27 finished with value: 0.6368046112917529 and parameters: {'learning_rate': 0.06853920113539567, 'max_depth': 9, 'min_child_weight': 5.471403888653278, 'colsample_bytree': 0.5427331092357226, 'subsample': 0.6392822969371699}. Best is trial 17 with value: 0.6448418563405263.
#
# [I 2025-03-01 22:57:28,596] Trial 28 finished with value: 0.6433697901271062 and parameters: {'learning_rate': 0.03538767992307834, 'max_depth': 8, 'min_child_weight': 2.4841270149983887, 'colsample_bytree': 0.7424816271303275, 'subsample': 0.8200751860319359}. Best is trial 17 with value: 0.6448418563405263.
#
# [I 2025-03-01 22:57:29,003] Trial 29 finished with value: 0.6372317469701448 and parameters: {'learning_rate': 0.08947432357890216, 'max_depth': 8, 'min_child_weight': 3.8566488480315355, 'colsample_bytree': 0.6545143769515575, 'subsample': 0.7147100841421568}. Best is trial 17 with value: 0.6448418563405263.
#
# [I 2025-03-01 22:57:29,443] Trial 30 finished with value: 0.631340526160213 and parameters: {'learning_rate': 0.12858329156031273, 'max_depth': 7, 'min_child_weight': 1.454002913368952, 'colsample_bytree': 0.8654113478253084, 'subsample': 0.6299320679362881}. Best is trial 17 with value: 0.6448418563405263.
#
# [I 2025-03-01 22:57:29,845] Trial 31 finished with value: 0.648273721548921 and parameters: {'learning_rate': 0.028634412752412408, 'max_depth': 8, 'min_child_weight': 2.4846695677281376, 'colsample_bytree': 0.7405323694747492, 'subsample': 0.8154578182818408}. Best is trial 31 with value: 0.648273721548921.
#
# [I 2025-03-01 22:57:30,436] Trial 32 finished with value: 0.6470410877919006 and parameters: {'learning_rate': 0.032772213662208755, 'max_depth': 9, 'min_child_weight': 1.1623716577930265, 'colsample_bytree': 0.832577243539439, 'subsample': 0.8325264532157746}. Best is trial 31 with value: 0.648273721548921.
#
# [I 2025-03-01 22:57:31,077] Trial 33 finished with value: 0.6403414129470884 and parameters: {'learning_rate': 0.02768789646635003, 'max_depth': 9, 'min_child_weight': 1.4771662323121941, 'colsample_bytree': 0.8270555853161007, 'subsample': 0.8060780186108994}. Best is trial 31 with value: 0.648273721548921.
#
# [I 2025-03-01 22:57:31,561] Trial 34 finished with value: 0.6383638782146024 and parameters: {'learning_rate': 0.06608267833394502, 'max_depth': 10, 'min_child_weight': 2.277373228889068, 'colsample_bytree': 0.9178119081759432, 'subsample': 0.823824577628731}. Best is trial 31 with value: 0.648273721548921.
#
# [I 2025-03-01 22:57:32,142] Trial 35 finished with value: 0.6460574933490985 and parameters: {'learning_rate': 0.0260270472057279, 'max_depth': 9, 'min_child_weight': 1.7940741263054565, 'colsample_bytree': 0.6881165077012819, 'subsample': 0.9581258781037608}. Best is trial 31 with value: 0.648273721548921.
#
# [I 2025-03-01 22:57:32,746] Trial 36 finished with value: 0.6454759089565474 and parameters: {'learning_rate': 0.027418012170672308, 'max_depth': 10, 'min_child_weight': 1.8645314602655354, 'colsample_bytree': 0.6819210315189558, 'subsample': 0.9933652383385134}. Best is trial 31 with value: 0.648273721548921.
#
# [I 2025-03-01 22:57:33,332] Trial 37 finished with value: 0.6421733668341709 and parameters: {'learning_rate': 0.010630329034004725, 'max_depth': 10, 'min_child_weight': 1.9355778211858952, 'colsample_bytree': 0.6779901714974477, 'subsample': 0.9853072558451272}. Best is trial 31 with value: 0.648273721548921.
#
# [I 2025-03-01 22:57:33,751] Trial 38 finished with value: 0.6428850133018031 and parameters: {'learning_rate': 0.07887557345120957, 'max_depth': 9, 'min_child_weight': 1.0431170133861871, 'colsample_bytree': 0.8223387103175899, 'subsample': 0.9411069698546951}. Best is trial 31 with value: 0.648273721548921.
#
# [I 2025-03-01 22:57:34,229] Trial 39 finished with value: 0.6483801359739876 and parameters: {'learning_rate': 0.02889358237253818, 'max_depth': 10, 'min_child_weight': 1.8157944795900882, 'colsample_bytree': 0.4647940538245444, 'subsample': 0.9577151135252858}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:34,566] Trial 40 finished with value: 0.640950339934969 and parameters: {'learning_rate': 0.09690050004614317, 'max_depth': 9, 'min_child_weight': 1.1645358356645867, 'colsample_bytree': 0.350270224762243, 'subsample': 0.9456227454956567}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:35,072] Trial 41 finished with value: 0.6457759385161099 and parameters: {'learning_rate': 0.02901732772354612, 'max_depth': 10, 'min_child_weight': 1.8335909901030938, 'colsample_bytree': 0.4568824966498473, 'subsample': 0.9630852169513936}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:35,478] Trial 42 finished with value: 0.6397147502216967 and parameters: {'learning_rate': 0.07472491581280526, 'max_depth': 10, 'min_child_weight': 1.6327076324304377, 'colsample_bytree': 0.4456841078582758, 'subsample': 0.9077034668975544}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:35,883] Trial 43 finished with value: 0.6457109074785693 and parameters: {'learning_rate': 0.028754438153862787, 'max_depth': 9, 'min_child_weight': 2.706969607851334, 'colsample_bytree': 0.47574845614456807, 'subsample': 0.8484579925588177}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:36,360] Trial 44 finished with value: 0.6469893585574934 and parameters: {'learning_rate': 0.023631486178160695, 'max_depth': 10, 'min_child_weight': 3.2153784747232566, 'colsample_bytree': 0.5180828139561907, 'subsample': 0.9600241729030402}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:36,947] Trial 45 finished with value: 0.6458513154005321 and parameters: {'learning_rate': 0.017647191939635987, 'max_depth': 9, 'min_child_weight': 3.294477801137882, 'colsample_bytree': 0.5130296449521565, 'subsample': 0.9065166667940278}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:37,731] Trial 46 finished with value: 0.6431525273425953 and parameters: {'learning_rate': 0.010126640779420697, 'max_depth': 10, 'min_child_weight': 2.3732824264083243, 'colsample_bytree': 0.5620737112785819, 'subsample': 0.8593806646608392}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:38,104] Trial 47 finished with value: 0.6460678391959799 and parameters: {'learning_rate': 0.060425375652048384, 'max_depth': 9, 'min_child_weight': 3.0003277353046016, 'colsample_bytree': 0.49718186603089126, 'subsample': 0.9538673328583318}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:38,650] Trial 48 finished with value: 0.6439639373337275 and parameters: {'learning_rate': 0.05713811027915997, 'max_depth': 10, 'min_child_weight': 3.5458910177607974, 'colsample_bytree': 0.3599137148183985, 'subsample': 0.921093585933756}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:39,163] Trial 49 finished with value: 0.6418637304167898 and parameters: {'learning_rate': 0.043511912376400036, 'max_depth': 9, 'min_child_weight': 2.8553974315053434, 'colsample_bytree': 0.5084963011065253, 'subsample': 0.7909340907913592}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:39,617] Trial 50 finished with value: 0.61228791013893 and parameters: {'learning_rate': 0.20454870653685853, 'max_depth': 10, 'min_child_weight': 3.109730500750288, 'colsample_bytree': 0.43105830330851863, 'subsample': 0.8902273874458805}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:40,301] Trial 51 finished with value: 0.6451226721844516 and parameters: {'learning_rate': 0.02108613220972874, 'max_depth': 9, 'min_child_weight': 1.0038113313223367, 'colsample_bytree': 0.5549501468770759, 'subsample': 0.9639955461335783}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:40,813] Trial 52 finished with value: 0.647422406148389 and parameters: {'learning_rate': 0.06403593948869842, 'max_depth': 9, 'min_child_weight': 2.2427557149085553, 'colsample_bytree': 0.4919439819301029, 'subsample': 0.9468343062201203}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:41,236] Trial 53 finished with value: 0.6427549512267219 and parameters: {'learning_rate': 0.06373552278105407, 'max_depth': 8, 'min_child_weight': 2.2071608985883056, 'colsample_bytree': 0.4887178090602153, 'subsample': 0.9296910574929166}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:41,741] Trial 54 finished with value: 0.6119154596511972 and parameters: {'learning_rate': 0.17942121005108125, 'max_depth': 10, 'min_child_weight': 2.5520017593205657, 'colsample_bytree': 0.42008297288746355, 'subsample': 0.8459385237046564}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:42,141] Trial 55 finished with value: 0.6475805498078628 and parameters: {'learning_rate': 0.052450203795558085, 'max_depth': 8, 'min_child_weight': 3.5547518705982846, 'colsample_bytree': 0.3719533498461761, 'subsample': 0.9963282580653227}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:42,553] Trial 56 finished with value: 0.6459872893881171 and parameters: {'learning_rate': 0.048022455791503396, 'max_depth': 8, 'min_child_weight': 4.307769392040453, 'colsample_bytree': 0.3827256346227477, 'subsample': 0.9782949214263816}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:42,770] Trial 57 finished with value: 0.6310804020100502 and parameters: {'learning_rate': 0.25216483149641716, 'max_depth': 3, 'min_child_weight': 1.3422621304411173, 'colsample_bytree': 0.33292333368315336, 'subsample': 0.760584704637925}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:43,197] Trial 58 finished with value: 0.6305010345846882 and parameters: {'learning_rate': 0.07335582557562065, 'max_depth': 8, 'min_child_weight': 3.36862991523384, 'colsample_bytree': 0.9380940292937717, 'subsample': 0.9974168642668315}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:43,626] Trial 59 finished with value: 0.644051138043157 and parameters: {'learning_rate': 0.03930693654621636, 'max_depth': 9, 'min_child_weight': 3.5121844525337655, 'colsample_bytree': 0.38694865310264204, 'subsample': 0.8987721139245447}. Best is trial 39 with value: 0.6483801359739876.
#
# [I 2025-03-01 22:57:44,090] Trial 60 finished with value: 0.6519893585574934 and parameters: {'learning_rate': 0.04937467950645991, 'max_depth': 10, 'min_child_weight': 9.610507720190547, 'colsample_bytree': 0.4645665340497741, 'subsample': 0.93289346276922}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:44,476] Trial 61 finished with value: 0.6428850133018031 and parameters: {'learning_rate': 0.05483845563308411, 'max_depth': 10, 'min_child_weight': 8.92837108444264, 'colsample_bytree': 0.4670580060956776, 'subsample': 0.9283103454940046}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:44,907] Trial 62 finished with value: 0.6407537688442211 and parameters: {'learning_rate': 0.038920777299539515, 'max_depth': 10, 'min_child_weight': 9.77982150728793, 'colsample_bytree': 0.5781185965515794, 'subsample': 0.9738048154502705}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:45,311] Trial 63 finished with value: 0.6258114099911322 and parameters: {'learning_rate': 0.11438269045990737, 'max_depth': 10, 'min_child_weight': 8.436998935203594, 'colsample_bytree': 0.30724149661573885, 'subsample': 0.9353206321079693}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:45,797] Trial 64 finished with value: 0.6403295891220809 and parameters: {'learning_rate': 0.01902980949786936, 'max_depth': 9, 'min_child_weight': 2.2241840905550108, 'colsample_bytree': 0.5323878029203674, 'subsample': 0.870519588041362}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:46,219] Trial 65 finished with value: 0.6316006503103754 and parameters: {'learning_rate': 0.08850575627233345, 'max_depth': 10, 'min_child_weight': 6.840946706905859, 'colsample_bytree': 0.42887903374141634, 'subsample': 0.7455067563951675}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:46,700] Trial 66 finished with value: 0.6460168489506355 and parameters: {'learning_rate': 0.05012562159735118, 'max_depth': 9, 'min_child_weight': 2.6484149955923435, 'colsample_bytree': 0.4127360389700998, 'subsample': 0.9785290764718102}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:47,097] Trial 67 finished with value: 0.6438131835648833 and parameters: {'learning_rate': 0.03271125939809748, 'max_depth': 8, 'min_child_weight': 7.64750760139703, 'colsample_bytree': 0.3723134390239197, 'subsample': 0.7237250037697559}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:47,662] Trial 68 finished with value: 0.6358291457286431 and parameters: {'learning_rate': 0.04796963127888629, 'max_depth': 10, 'min_child_weight': 4.273674274399038, 'colsample_bytree': 0.6358707560074387, 'subsample': 0.7783573846379148}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:48,090] Trial 69 finished with value: 0.6422317469701447 and parameters: {'learning_rate': 0.08309284737485258, 'max_depth': 9, 'min_child_weight': 1.6816642756787679, 'colsample_bytree': 0.4497140856931923, 'subsample': 0.9997276968058684}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:48,441] Trial 70 finished with value: 0.6433210168489506 and parameters: {'learning_rate': 0.06695663199287907, 'max_depth': 8, 'min_child_weight': 6.064942101567085, 'colsample_bytree': 0.5209015183891187, 'subsample': 0.834552434349715}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:48,889] Trial 71 finished with value: 0.6422406148389004 and parameters: {'learning_rate': 0.059322094555730676, 'max_depth': 9, 'min_child_weight': 2.052484257697383, 'colsample_bytree': 0.4947622554944428, 'subsample': 0.9596666007772289}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:49,403] Trial 72 finished with value: 0.6452586461720367 and parameters: {'learning_rate': 0.01888367519426103, 'max_depth': 9, 'min_child_weight': 2.9191462483442865, 'colsample_bytree': 0.4931603411974805, 'subsample': 0.9520315782579274}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:50,115] Trial 73 finished with value: 0.6389964528524978 and parameters: {'learning_rate': 0.03555615949709859, 'max_depth': 10, 'min_child_weight': 3.6941571436874083, 'colsample_bytree': 0.8009053819267644, 'subsample': 0.8730753644409492}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:50,623] Trial 74 finished with value: 0.6455172923440733 and parameters: {'learning_rate': 0.05563224556784373, 'max_depth': 9, 'min_child_weight': 3.1491215133031636, 'colsample_bytree': 0.5845280770875568, 'subsample': 0.9114100881604541}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:51,100] Trial 75 finished with value: 0.6452290866095183 and parameters: {'learning_rate': 0.024486903490321447, 'max_depth': 8, 'min_child_weight': 1.3064391883342443, 'colsample_bytree': 0.7113708900242566, 'subsample': 0.9403480841627379}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:51,604] Trial 76 finished with value: 0.6443319538870825 and parameters: {'learning_rate': 0.07248561901223013, 'max_depth': 10, 'min_child_weight': 2.9274783520118834, 'colsample_bytree': 0.40022315271906517, 'subsample': 0.9689642587646663}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:51,974] Trial 77 finished with value: 0.6429589122080994 and parameters: {'learning_rate': 0.042557959514021124, 'max_depth': 7, 'min_child_weight': 2.46404169285067, 'colsample_bytree': 0.3309200263671144, 'subsample': 0.9491845658445514}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:52,695] Trial 78 finished with value: 0.6436964232929352 and parameters: {'learning_rate': 0.03235827997663128, 'max_depth': 9, 'min_child_weight': 1.5938774291644906, 'colsample_bytree': 0.859526240634154, 'subsample': 0.9168343309616928}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:53,194] Trial 79 finished with value: 0.6283417085427137 and parameters: {'learning_rate': 0.09709529207898579, 'max_depth': 10, 'min_child_weight': 4.503693760717287, 'colsample_bytree': 0.7587091078904603, 'subsample': 0.6966325017552866}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:53,599] Trial 80 finished with value: 0.6267691398167308 and parameters: {'learning_rate': 0.1484713674725121, 'max_depth': 8, 'min_child_weight': 2.0076080426767438, 'colsample_bytree': 0.4663590098571585, 'subsample': 0.8948816339734137}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:54,259] Trial 81 finished with value: 0.6464883239728052 and parameters: {'learning_rate': 0.02216792350522669, 'max_depth': 9, 'min_child_weight': 1.7702880215901091, 'colsample_bytree': 0.7015686869935278, 'subsample': 0.9887549111224834}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:54,886] Trial 82 finished with value: 0.6458054980786285 and parameters: {'learning_rate': 0.014054475572291674, 'max_depth': 9, 'min_child_weight': 2.192780889728656, 'colsample_bytree': 0.6501300804121739, 'subsample': 0.9814934121359937}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:55,526] Trial 83 finished with value: 0.644379249187112 and parameters: {'learning_rate': 0.026146035412419288, 'max_depth': 9, 'min_child_weight': 1.3537765462300977, 'colsample_bytree': 0.6309291788854082, 'subsample': 0.9884333811402878}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:56,073] Trial 84 finished with value: 0.6489048182086905 and parameters: {'learning_rate': 0.044319894038215756, 'max_depth': 9, 'min_child_weight': 2.7244254089979503, 'colsample_bytree': 0.5499033736185923, 'subsample': 0.9514207968387182}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:56,682] Trial 85 finished with value: 0.634689624593556 and parameters: {'learning_rate': 0.0440826317788632, 'max_depth': 10, 'min_child_weight': 2.676527269269943, 'colsample_bytree': 0.5425061610554405, 'subsample': 0.8046637271963522}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:57,016] Trial 86 finished with value: 0.6433357966302099 and parameters: {'learning_rate': 0.03289392696826922, 'max_depth': 6, 'min_child_weight': 1.7808336084218828, 'colsample_bytree': 0.7110241848991677, 'subsample': 0.9695971286976567}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:57,317] Trial 87 finished with value: 0.6352002660360627 and parameters: {'learning_rate': 0.02179474539173629, 'max_depth': 4, 'min_child_weight': 2.3014005610903157, 'colsample_bytree': 0.5656209646313213, 'subsample': 0.9240111456120809}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:57,920] Trial 88 finished with value: 0.6409399940880876 and parameters: {'learning_rate': 0.012976079370986125, 'max_depth': 8, 'min_child_weight': 1.1453621596192454, 'colsample_bytree': 0.7985586537586222, 'subsample': 0.9468977827048733}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:58,391] Trial 89 finished with value: 0.6146526751404079 and parameters: {'learning_rate': 0.234531853134893, 'max_depth': 9, 'min_child_weight': 1.5608045894432852, 'colsample_bytree': 0.6637659544485214, 'subsample': 0.9866697296411319}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:58,854] Trial 90 finished with value: 0.6425509902453443 and parameters: {'learning_rate': 0.05070940885483872, 'max_depth': 10, 'min_child_weight': 6.9351504328270694, 'colsample_bytree': 0.528910002114226, 'subsample': 0.9359589689873372}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:59,396] Trial 91 finished with value: 0.6469065917824416 and parameters: {'learning_rate': 0.03856485953890579, 'max_depth': 9, 'min_child_weight': 3.1161117429147076, 'colsample_bytree': 0.5066956718764434, 'subsample': 0.9584403147275725}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:57:59,894] Trial 92 finished with value: 0.643526455808454 and parameters: {'learning_rate': 0.034130407906738165, 'max_depth': 9, 'min_child_weight': 3.7019652034514325, 'colsample_bytree': 0.43769670623850104, 'subsample': 0.9733176740936135}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:00,500] Trial 93 finished with value: 0.6480653266331659 and parameters: {'learning_rate': 0.04055655929813335, 'max_depth': 8, 'min_child_weight': 3.2245157075543194, 'colsample_bytree': 0.5996835687803882, 'subsample': 0.9620046221274129}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:00,891] Trial 94 finished with value: 0.6484451670115283 and parameters: {'learning_rate': 0.040873299692889845, 'max_depth': 8, 'min_child_weight': 3.140140969113981, 'colsample_bytree': 0.6046598784761007, 'subsample': 0.959497841326339}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:01,372] Trial 95 finished with value: 0.6426101093703813 and parameters: {'learning_rate': 0.06485517599201515, 'max_depth': 8, 'min_child_weight': 3.413308746081448, 'colsample_bytree': 0.5952274780068283, 'subsample': 0.881752513096718}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:01,896] Trial 96 finished with value: 0.6213272243570795 and parameters: {'learning_rate': 0.2937365607124856, 'max_depth': 7, 'min_child_weight': 2.815830126115322, 'colsample_bytree': 0.6149312087630437, 'subsample': 0.9017783805520558}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:02,443] Trial 97 finished with value: 0.6434422110552763 and parameters: {'learning_rate': 0.05298639504112525, 'max_depth': 8, 'min_child_weight': 4.179361405667335, 'colsample_bytree': 0.5500086232568747, 'subsample': 0.9339928253322665}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:02,926] Trial 98 finished with value: 0.6445359148684598 and parameters: {'learning_rate': 0.04450445754343826, 'max_depth': 8, 'min_child_weight': 3.7855197177861166, 'colsample_bytree': 0.5698943406438948, 'subsample': 0.9640773749464184}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:03,319] Trial 99 finished with value: 0.6482751995270469 and parameters: {'learning_rate': 0.0612038063899445, 'max_depth': 7, 'min_child_weight': 2.447143387469306, 'colsample_bytree': 0.4762875868541081, 'subsample': 0.9124449162572805}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:03,729] Trial 100 finished with value: 0.6459555128584096 and parameters: {'learning_rate': 0.06992238561665248, 'max_depth': 7, 'min_child_weight': 2.519653795558311, 'colsample_bytree': 0.4792529549749376, 'subsample': 0.9143737724701869}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:04,033] Trial 101 finished with value: 0.6394117647058823 and parameters: {'learning_rate': 0.08126957394417854, 'max_depth': 7, 'min_child_weight': 3.109439981032489, 'colsample_bytree': 0.46089759513466816, 'subsample': 0.9452946899756646}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:04,388] Trial 102 finished with value: 0.6493363878214603 and parameters: {'learning_rate': 0.058249113651118165, 'max_depth': 7, 'min_child_weight': 2.436034387127217, 'colsample_bytree': 0.5973389492656541, 'subsample': 0.9276347561270066}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:04,662] Trial 103 finished with value: 0.6439506355305942 and parameters: {'learning_rate': 0.06044719913429289, 'max_depth': 6, 'min_child_weight': 2.039479502392677, 'colsample_bytree': 0.6328063429362087, 'subsample': 0.9226031453251643}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:04,985] Trial 104 finished with value: 0.6430062075081289 and parameters: {'learning_rate': 0.048491187520853046, 'max_depth': 7, 'min_child_weight': 2.382770321840949, 'colsample_bytree': 0.6026780688171205, 'subsample': 0.888566921964108}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:05,279] Trial 105 finished with value: 0.6451670115282293 and parameters: {'learning_rate': 0.06195428459104006, 'max_depth': 7, 'min_child_weight': 2.537078775844988, 'colsample_bytree': 0.6021448968277697, 'subsample': 0.86473334783997}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:05,644] Trial 106 finished with value: 0.6496349394028968 and parameters: {'learning_rate': 0.03992833487938719, 'max_depth': 8, 'min_child_weight': 2.7636067836427913, 'colsample_bytree': 0.580720786092523, 'subsample': 0.9283051899660061}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:06,060] Trial 107 finished with value: 0.6454670410877918 and parameters: {'learning_rate': 0.04082227294015363, 'max_depth': 8, 'min_child_weight': 2.6869731147095983, 'colsample_bytree': 0.5432629011626844, 'subsample': 0.9357352257978867}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:06,502] Trial 108 finished with value: 0.6457921962754951 and parameters: {'learning_rate': 0.07717181259129748, 'max_depth': 8, 'min_child_weight': 2.885858546405629, 'colsample_bytree': 0.5739586395892684, 'subsample': 0.951359009136789}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:06,892] Trial 109 finished with value: 0.6451803133313627 and parameters: {'learning_rate': 0.057342712931401696, 'max_depth': 7, 'min_child_weight': 3.5226847557024756, 'colsample_bytree': 0.6255149232061818, 'subsample': 0.9264121551610286}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:07,296] Trial 110 finished with value: 0.6418592964824121 and parameters: {'learning_rate': 0.05353348836919991, 'max_depth': 8, 'min_child_weight': 2.1732117472298196, 'colsample_bytree': 0.594218853835753, 'subsample': 0.9099835906439789}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:07,878] Trial 111 finished with value: 0.6430741945019214 and parameters: {'learning_rate': 0.028249049340581672, 'max_depth': 8, 'min_child_weight': 1.922177775517849, 'colsample_bytree': 0.9197110058052673, 'subsample': 0.9783895230030062}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:08,363] Trial 112 finished with value: 0.6414705882352942 and parameters: {'learning_rate': 0.04580158274604011, 'max_depth': 8, 'min_child_weight': 2.3504663132323858, 'colsample_bytree': 0.6699428198886915, 'subsample': 0.8494846002575713}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:08,759] Trial 113 finished with value: 0.6425908956547444 and parameters: {'learning_rate': 0.0365036101018957, 'max_depth': 8, 'min_child_weight': 9.506681407915535, 'colsample_bytree': 0.5286307842578913, 'subsample': 0.9419503111462219}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:09,130] Trial 114 finished with value: 0.6423130357670707 and parameters: {'learning_rate': 0.03240100643495213, 'max_depth': 7, 'min_child_weight': 3.3263044155079378, 'colsample_bytree': 0.5574936239467732, 'subsample': 0.8181727484958677}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:09,505] Trial 115 finished with value: 0.6424785693171742 and parameters: {'learning_rate': 0.06965236573615523, 'max_depth': 8, 'min_child_weight': 2.7633446874525296, 'colsample_bytree': 0.48193133937959065, 'subsample': 0.9984540704534389}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:09,829] Trial 116 finished with value: 0.6333224948270766 and parameters: {'learning_rate': 0.17503749614086328, 'max_depth': 7, 'min_child_weight': 5.426411295889222, 'colsample_bytree': 0.7385093633748452, 'subsample': 0.9558302794887136}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:10,161] Trial 117 finished with value: 0.6473307715045817 and parameters: {'learning_rate': 0.0505011336278081, 'max_depth': 7, 'min_child_weight': 2.996988909137187, 'colsample_bytree': 0.4096743362601359, 'subsample': 0.9009239328085242}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:10,460] Trial 118 finished with value: 0.64228791013893 and parameters: {'learning_rate': 0.051391510654234286, 'max_depth': 6, 'min_child_weight': 3.241278341092887, 'colsample_bytree': 0.369832306029329, 'subsample': 0.9012836449754458}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:10,809] Trial 119 finished with value: 0.6402763819095476 and parameters: {'learning_rate': 0.08572748334631435, 'max_depth': 7, 'min_child_weight': 3.00788749339946, 'colsample_bytree': 0.419487760029921, 'subsample': 0.9180515158797743}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:11,176] Trial 120 finished with value: 0.6450990245344369 and parameters: {'learning_rate': 0.06241321258036948, 'max_depth': 7, 'min_child_weight': 2.553639112502985, 'colsample_bytree': 0.40474501442128913, 'subsample': 0.9680789522974602}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:11,552] Trial 121 finished with value: 0.646820869051138 and parameters: {'learning_rate': 0.04339793147975792, 'max_depth': 7, 'min_child_weight': 2.13128026428605, 'colsample_bytree': 0.4477388034006249, 'subsample': 0.9291639060126919}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:12,019] Trial 122 finished with value: 0.6417321903635826 and parameters: {'learning_rate': 0.029987761701139936, 'max_depth': 8, 'min_child_weight': 2.7629831538702514, 'colsample_bytree': 0.3429212244039245, 'subsample': 0.880645345896095}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:12,432] Trial 123 finished with value: 0.6457271652379545 and parameters: {'learning_rate': 0.03962469699731476, 'max_depth': 8, 'min_child_weight': 8.155442374308468, 'colsample_bytree': 0.5826250280369298, 'subsample': 0.7867090783013192}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:12,728] Trial 124 finished with value: 0.6421415903044635 and parameters: {'learning_rate': 0.05763338959405072, 'max_depth': 6, 'min_child_weight': 2.390569283071425, 'colsample_bytree': 0.43547865149823367, 'subsample': 0.9588344220542668}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:13,049] Trial 125 finished with value: 0.6416612474135382 and parameters: {'learning_rate': 0.05063266754100386, 'max_depth': 5, 'min_child_weight': 3.594757373076232, 'colsample_bytree': 0.5034913372519367, 'subsample': 0.9462945184093082}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:13,516] Trial 126 finished with value: 0.6426189772391369 and parameters: {'learning_rate': 0.04563898625637947, 'max_depth': 8, 'min_child_weight': 3.032908658949384, 'colsample_bytree': 0.8370330792686709, 'subsample': 0.8329420779788093}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:13,909] Trial 127 finished with value: 0.6446305054685191 and parameters: {'learning_rate': 0.01632087525939719, 'max_depth': 7, 'min_child_weight': 1.897982461256009, 'colsample_bytree': 0.3925271211319165, 'subsample': 0.8920878268241306}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:14,387] Trial 128 finished with value: 0.6491457286432161 and parameters: {'learning_rate': 0.03720893820606652, 'max_depth': 8, 'min_child_weight': 1.4580344144800181, 'colsample_bytree': 0.648086842730503, 'subsample': 0.9088505694203095}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:14,841] Trial 129 finished with value: 0.6439513745196572 and parameters: {'learning_rate': 0.03700536109724709, 'max_depth': 8, 'min_child_weight': 3.9735035587302585, 'colsample_bytree': 0.6458229832940802, 'subsample': 0.9076920752597338}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:15,331] Trial 130 finished with value: 0.6464572864321608 and parameters: {'learning_rate': 0.025118023812274348, 'max_depth': 7, 'min_child_weight': 1.5545196498644258, 'colsample_bytree': 0.6080786685952032, 'subsample': 0.9375919849210063}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:15,874] Trial 131 finished with value: 0.6466420336979013 and parameters: {'learning_rate': 0.03168231704509099, 'max_depth': 8, 'min_child_weight': 1.2293591895438771, 'colsample_bytree': 0.7787086406156807, 'subsample': 0.9194687468477536}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:16,403] Trial 132 finished with value: 0.6452896837126811 and parameters: {'learning_rate': 0.054557154770556074, 'max_depth': 8, 'min_child_weight': 1.3905592176951294, 'colsample_bytree': 0.6251485815204213, 'subsample': 0.9728594791735994}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:16,809] Trial 133 finished with value: 0.6433402305645877 and parameters: {'learning_rate': 0.039744455116713796, 'max_depth': 8, 'min_child_weight': 1.703113302650431, 'colsample_bytree': 0.4642517171839523, 'subsample': 0.8973618870644465}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:17,439] Trial 134 finished with value: 0.6371667159326042 and parameters: {'learning_rate': 0.06794798054151654, 'max_depth': 9, 'min_child_weight': 1.0213948521798983, 'colsample_bytree': 0.6443021215455099, 'subsample': 0.930608832290043}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:17,942] Trial 135 finished with value: 0.6467129766479456 and parameters: {'learning_rate': 0.04667631139602948, 'max_depth': 9, 'min_child_weight': 2.611038724459635, 'colsample_bytree': 0.5856655692933576, 'subsample': 0.947320893656791}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:18,766] Trial 136 finished with value: 0.641162429796039 and parameters: {'learning_rate': 0.02376201612925725, 'max_depth': 9, 'min_child_weight': 2.269184859300273, 'colsample_bytree': 0.8170127900307292, 'subsample': 0.9899202432639082}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:19,238] Trial 137 finished with value: 0.6301123263375702 and parameters: {'learning_rate': 0.12475101282201018, 'max_depth': 7, 'min_child_weight': 2.809724392169755, 'colsample_bytree': 0.8908986831836039, 'subsample': 0.8590219553221914}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:19,732] Trial 138 finished with value: 0.6399556606562222 and parameters: {'learning_rate': 0.06467943788490883, 'max_depth': 8, 'min_child_weight': 1.997859928098013, 'colsample_bytree': 0.518779434162359, 'subsample': 0.9667358362379143}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:20,246] Trial 139 finished with value: 0.643468814661543 and parameters: {'learning_rate': 0.040499208502094174, 'max_depth': 8, 'min_child_weight': 3.2493632201722473, 'colsample_bytree': 0.6624408581457322, 'subsample': 0.8760311758125583}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:20,973] Trial 140 finished with value: 0.6404478273721549 and parameters: {'learning_rate': 0.01595072405107763, 'max_depth': 10, 'min_child_weight': 1.5219110755939727, 'colsample_bytree': 0.4760111086356388, 'subsample': 0.909005044983033}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:21,649] Trial 141 finished with value: 0.6474091043452557 and parameters: {'learning_rate': 0.028950629543650838, 'max_depth': 10, 'min_child_weight': 2.9797160675302576, 'colsample_bytree': 0.49312266470613203, 'subsample': 0.9577917267767129}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:22,282] Trial 142 finished with value: 0.6460094590600058 and parameters: {'learning_rate': 0.028809636406413222, 'max_depth': 10, 'min_child_weight': 2.9063160455949952, 'colsample_bytree': 0.6167612156928605, 'subsample': 0.9527070375642388}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:22,938] Trial 143 finished with value: 0.6444945314809342 and parameters: {'learning_rate': 0.03472488207396643, 'max_depth': 10, 'min_child_weight': 2.495369077689179, 'colsample_bytree': 0.45660392758736396, 'subsample': 0.982598753833163}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:23,452] Trial 144 finished with value: 0.6460404966006503 and parameters: {'learning_rate': 0.05097681231899, 'max_depth': 10, 'min_child_weight': 7.172778119866512, 'colsample_bytree': 0.5371372629289624, 'subsample': 0.9234429087124607}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:24,084] Trial 145 finished with value: 0.6449246231155779 and parameters: {'learning_rate': 0.02135086378202506, 'max_depth': 9, 'min_child_weight': 3.1178802928761464, 'colsample_bytree': 0.9666129900861423, 'subsample': 0.9412860376018002}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:24,583] Trial 146 finished with value: 0.6383624002364765 and parameters: {'learning_rate': 0.056789183858348385, 'max_depth': 10, 'min_child_weight': 3.3598351554176147, 'colsample_bytree': 0.4941390298488986, 'subsample': 0.9587649421930597}. Best is trial 60 with value: 0.6519893585574934.
#
# [I 2025-03-01 22:58:25,056] Trial 147 finished with value: 0.644284658587053 and parameters: {'learning_rate': 0.04681010130071413, 'max_depth': 8, 'min_child_weight': 2.6622194367204415, 'colsample_bytree': 0.5628282241936169, 'subsample': 0.9358257348225991}. Best is trial 60 with value: 0.6519893585574934.
#
# ...
#   8%|==                  | 137/1646 [00:16<02:56]
#   9%|==                  | 149/1646 [00:17<02:50]
#  10%|==                  | 158/1646 [00:18<02:49]
#  10%|==                  | 170/1646 [00:19<02:44]
#  11%|==                  | 180/1646 [00:20<02:42]
#  12%|==                  | 193/1646 [00:21<02:38]
#  12%|==                  | 201/1646 [00:22<02:38]
#  13%|===                 | 209/1646 [00:23<02:38]
#  13%|===                 | 219/1646 [00:24<02:36]
#  14%|===                 | 228/1646 [00:25<02:35]
#  14%|===                 | 237/1646 [00:26<02:34]
#  15%|===                 | 246/1646 [00:27<02:33]
#  16%|===                 | 257/1646 [00:28<02:31]
#  16%|===                 | 267/1646 [00:29<02:29]
#  17%|===                 | 276/1646 [00:30<02:28]
#  17%|===                 | 285/1646 [00:31<02:28]
#  18%|====                | 296/1646 [00:32<02:25]
#  19%|====                | 307/1646 [00:33<02:23]
#  19%|====                | 316/1646 [00:34<02:23]
#  20%|====                | 327/1646 [00:35<02:21]
#  20%|====                | 334/1646 [00:36<02:21]
#  21%|====                | 342/1646 [00:37<02:21]
#  21%|====                | 352/1646 [00:38<02:19]
#  22%|====                | 361/1646 [00:39<02:18]
#  22%|====                | 370/1646 [00:40<02:17]
#  23%|=====               | 381/1646 [00:41<02:16]
#  24%|=====               | 389/1646 [00:42<02:15]
#  24%|=====               | 401/1646 [00:43<02:13]
#  25%|=====               | 413/1646 [00:44<02:11]
#  26%|=====               | 424/1646 [00:45<02:09]
#  27%|=====               | 437/1646 [00:46<02:07]
#  27%|=====               | 448/1646 [00:47<02:05]
#  28%|======              | 458/1646 [00:48<02:04]
#  28%|======              | 468/1646 [00:49<02:03]
#  29%|======              | 477/1646 [00:50<02:02]
#  30%|======              | 489/1646 [00:51<02:00]
#  30%|======              | 498/1646 [00:52<01:59]
#  31%|======              | 508/1646 [00:53<01:58]
#  31%|======              | 516/1646 [00:54<01:58]
#  32%|======              | 528/1646 [00:55<01:56]
#  33%|=======             | 539/1646 [00:56<01:55]
#  33%|=======             | 548/1646 [00:57<01:54]
#  34%|=======             | 559/1646 [00:58<01:52]
#  35%|=======             | 569/1646 [00:59<01:51]
#  35%|=======             | 577/1646 [01:00<01:51]
#  36%|=======             | 587/1646 [01:01<01:50]
#  36%|=======             | 599/1646 [01:02<01:48]
#  37%|=======             | 609/1646 [01:03<01:47]
#  37%|=======             | 615/1646 [01:04<01:47]
#  38%|========            | 623/1646 [01:05<01:46]
#  38%|========            | 630/1646 [01:06<01:46]
#  39%|========            | 639/1646 [01:07<01:45]
#  39%|========            | 650/1646 [01:08<01:44]
#  40%|========            | 660/1646 [01:09<01:43]
#  41%|========            | 669/1646 [01:10<01:42]
#  41%|========            | 678/1646 [01:11<01:41]
#  42%|========            | 687/1646 [01:12<01:40]
#  42%|========            | 698/1646 [01:13<01:39]
#  43%|=========           | 710/1646 [01:14<01:37]
#  44%|=========           | 723/1646 [01:15<01:35]
#  45%|=========           | 736/1646 [01:16<01:33]
#  45%|=========           | 746/1646 [01:17<01:32]
#  46%|=========           | 759/1646 [01:18<01:31]
#  47%|=========           | 771/1646 [01:19<01:29]
#  48%|==========          | 782/1646 [01:20<01:28]
#  48%|==========          | 794/1646 [01:21<01:26]
#  49%|==========          | 806/1646 [01:22<01:25]
#  50%|==========          | 818/1646 [01:23<01:24]
#  50%|==========          | 831/1646 [01:24<01:22]
#  51%|==========          | 843/1646 [01:25<01:20]
#  52%|==========          | 852/1646 [01:26<01:20]
#  52%|==========          | 859/1646 [01:27<01:19]
#  53%|===========         | 867/1646 [01:28<01:19]
#  53%|===========         | 879/1646 [01:29<01:17]
#  54%|===========         | 889/1646 [01:30<01:16]
#  54%|===========         | 897/1646 [01:31<01:15]
#  55%|===========         | 904/1646 [01:32<01:15]
#  55%|===========         | 913/1646 [01:33<01:14]
#  56%|===========         | 923/1646 [01:34<01:13]
#  57%|===========         | 934/1646 [01:35<01:12]
#  57%|===========         | 945/1646 [01:36<01:11]
#  58%|============        | 955/1646 [01:37<01:10]
#  59%|============        | 963/1646 [01:38<01:09]
#  59%|============        | 972/1646 [01:39<01:08]
#  60%|============        | 982/1646 [01:40<01:07]
#  60%|============        | 991/1646 [01:41<01:06]
#  61%|============        | 1000/1646 [01:42<01:05]
#  61%|============        | 1010/1646 [01:43<01:04]
#  62%|============        | 1019/1646 [01:44<01:03]
#  63%|=============       | 1029/1646 [01:45<01:02]
#  63%|=============       | 1040/1646 [01:46<01:01]
#  64%|=============       | 1050/1646 [01:47<01:00]
#  64%|=============       | 1060/1646 [01:48<00:59]
#  65%|=============       | 1071/1646 [01:49<00:58]
#  66%|=============       | 1083/1646 [01:50<00:57]
#  67%|=============       | 1095/1646 [01:51<00:55]
#  67%|=============       | 1107/1646 [01:52<00:54]
#  68%|==============      | 1118/1646 [01:53<00:53]
#  69%|==============      | 1128/1646 [01:54<00:52]
#  69%|==============      | 1135/1646 [01:55<00:51]
#  69%|==============      | 1143/1646 [01:56<00:51]
#  70%|==============      | 1153/1646 [01:57<00:50]
#  71%|==============      | 1162/1646 [01:58<00:49]
#  71%|==============      | 1171/1646 [01:59<00:48]
#  72%|==============      | 1181/1646 [02:00<00:47]
#  72%|==============      | 1191/1646 [02:01<00:46]
#  73%|===============     | 1200/1646 [02:02<00:45]
#  73%|===============     | 1208/1646 [02:03<00:44]
#  74%|===============     | 1216/1646 [02:04<00:43]
#  74%|===============     | 1224/1646 [02:05<00:43]
#  75%|===============     | 1232/1646 [02:06<00:42]
#  75%|===============     | 1241/1646 [02:07<00:41]
#  76%|===============     | 1251/1646 [02:08<00:40]
#  77%|===============     | 1262/1646 [02:09<00:39]
#  77%|===============     | 1272/1646 [02:10<00:38]
#  78%|================    | 1282/1646 [02:11<00:37]
#  78%|================    | 1292/1646 [02:12<00:36]
#  79%|================    | 1301/1646 [02:13<00:35]
#  80%|================    | 1311/1646 [02:14<00:34]
#  80%|================    | 1321/1646 [02:15<00:33]
#  81%|================    | 1331/1646 [02:16<00:32]
#  82%|================    | 1342/1646 [02:17<00:31]
#  82%|================    | 1353/1646 [02:18<00:29]
#  83%|=================   | 1366/1646 [02:19<00:28]
#  84%|=================   | 1378/1646 [02:20<00:27]
#  84%|=================   | 1388/1646 [02:21<00:26]
#  85%|=================   | 1397/1646 [02:22<00:25]
#  86%|=================   | 1409/1646 [02:23<00:24]
#  86%|=================   | 1418/1646 [02:24<00:23]
#  87%|=================   | 1427/1646 [02:25<00:22]
#  87%|=================   | 1436/1646 [02:26<00:21]
#  88%|==================  | 1446/1646 [02:27<00:20]
#  88%|==================  | 1453/1646 [02:28<00:19]
#  89%|==================  | 1463/1646 [02:29<00:18]
#  89%|==================  | 1472/1646 [02:30<00:17]
#  90%|==================  | 1481/1646 [02:31<00:16]
#  91%|==================  | 1490/1646 [02:32<00:15]
#  91%|==================  | 1502/1646 [02:33<00:14]
#  92%|==================  | 1512/1646 [02:34<00:13]
#  92%|==================  | 1519/1646 [02:35<00:12]
#  93%|=================== | 1531/1646 [02:36<00:11]
#  94%|=================== | 1544/1646 [02:37<00:10]
#  94%|=================== | 1555/1646 [02:38<00:09]
#  95%|=================== | 1565/1646 [02:39<00:08]
#  96%|=================== | 1575/1646 [02:40<00:07]
#  96%|=================== | 1586/1646 [02:41<00:06]
#  97%|=================== | 1593/1646 [02:42<00:05]
#  97%|=================== | 1604/1646 [02:43<00:04]
#  98%|===================| 1615/1646 [02:44<00:03]
#  99%|===================| 1626/1646 [02:45<00:02]
#  99%|===================| 1637/1646 [02:46<00:00]
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [23:08:47] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1738880431132/work/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
#
# Passed unknown parameter: N_Trials
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/20 [00:00<?, ?cell/s]
# /tmp/ipykernel_5530/2465601509.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   label_proportions = y_train.groupby(X_train_final["facet_category"]).mean()
# Notebook Deployment_Monitoring.ipynb failed:
# ---------------------------------------------------------------------------
# Exception encountered at "In [12]":
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 9
#       7 for category in quartile_labels:
#       8     subset = X_prod_final[X_prod_final["facet_category"] == category]
# ----> 9     preds = json.loads(mock_endpoint.predict(subset))["predictions"]
#      10     category_preds[category] = preds
#      12 # Compute acceptance rates per quartile
#
# Cell In[7], line 46, in MockEndpoint.predict(self, data)
#      44 def predict(self, data):
#      45     features = self.model.feature_names
# ---> 46     dmatrix = xgb.DMatrix(data[features])
#      47     predictions = self.model.predict(dmatrix)
#      49     return json.dumps({"predictions": predictions.tolist()})
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['n_inpatient_x_time_in_hospital', 'n_lab_procedures_x_time_in_hospital', 'n_medications_x_time_in_hospital'] not in index"
# ---------------------------------------------------------------------------
# PapermillExecutionError                   Traceback (most recent call last)
# Cell In[8], line 33, in run_cicd.<locals>.execute_notebook(notebook_path, node_name)
#      32 try:
# ---> 33     pm.execute_notebook(
#      34         notebook_path,
#      35         f"executed_{notebook_path}",  # Save output notebook
#      36         parameters=config_dict,  # Pass configuration dictionary
#      37         log_output=True
#      38     )
#      39     execution_results[node_name] = "success"
#
# File /opt/conda/lib/python3.11/site-packages/papermill/execute.py:131, in execute_notebook(input_path, output_path, parameters, engine_name, request_save_on_cell_execute, prepare_only, kernel_name, language, progress_bar, log_output, stdout_file, stderr_file, start_timeout, report_mode, cwd, **engine_kwargs)
#     130     # Check for errors first (it saves on error before raising)
# --> 131     raise_for_execution_errors(nb, output_path)
#     133 # Write final output in case the engine didn't write it on cell completion.
#
# File /opt/conda/lib/python3.11/site-packages/papermill/execute.py:251, in raise_for_execution_errors(nb, output_path)
#     250 write_ipynb(nb, output_path)
# --> 251 raise error
#
# PapermillExecutionError:
# ---------------------------------------------------------------------------
# Exception encountered at "In [12]":
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 9
#       7 for category in quartile_labels:
#       8     subset = X_prod_final[X_prod_final["facet_category"] == category]
# ----> 9     preds = json.loads(mock_endpoint.predict(subset))["predictions"]
#      10     category_preds[category] = preds
#      12 # Compute acceptance rates per quartile
#
# Cell In[7], line 46, in MockEndpoint.predict(self, data)
#      44 def predict(self, data):
#      45     features = self.model.feature_names
# ---> 46     dmatrix = xgb.DMatrix(data[features])
#      47     predictions = self.model.predict(dmatrix)
#      49     return json.dumps({"predictions": predictions.tolist()})
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['n_inpatient_x_time_in_hospital', 'n_lab_procedures_x_time_in_hospital', 'n_medications_x_time_in_hospital'] not in index"
#
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 4
#       1 success_config = {
#       2     "N_Trials": int(1000)
#       3 }
# ----> 4 run_cicd(success_config)
#
# Cell In[8], line 91, in run_cicd(config_dict)
#      89 # Execute Notebooks in Order
#      90 for notebook, node in notebooks.items():
# ---> 91     success = execute_notebook(notebook, node)
#      92     if not success:
#      93         break  # **Stop execution on failure**
#
# Cell In[8], line 67, in run_cicd.<locals>.execute_notebook(notebook_path, node_name)
#      64 plot_dag(dag, "CI/CD Pipeline Status - FAILURE")
#      66 # **Stop pipeline execution immediately**
# ---> 67 raise RuntimeError(f"Pipeline stopped due to failure in {node_name}")
#
# RuntimeError: Pipeline stopped due to failure in Model Deployment and Monitoring
