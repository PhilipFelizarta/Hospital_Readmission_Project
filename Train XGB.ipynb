# %%
# !pip install shap
# !pip install xgboost
# Out:
# Requirement already satisfied: shap in /opt/conda/lib/python3.11/site-packages (0.46.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.11/site-packages (from shap) (1.15.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.11/site-packages (from shap) (1.5.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from shap) (2.2.3)
# Requirement already satisfied: tqdm>=4.27.0 in /opt/conda/lib/python3.11/site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /opt/conda/lib/python3.11/site-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in /opt/conda/lib/python3.11/site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /opt/conda/lib/python3.11/site-packages (from shap) (0.61.0)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.11/site-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /opt/conda/lib/python3.11/site-packages (from numba->shap) (0.44.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->shap) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.11/site-packages (from xgboost) (1.15.1)

# %%
import pandas as pd
import numpy as np

import boto3
from pyathena import connect
import sagemaker
from sagemaker.feature_store.feature_group import FeatureGroup, FeatureDefinition, FeatureTypeEnum
from sagemaker.session import Session
from sagemaker import get_execution_role

from pyathena import connect

import time
import shap
import json
import joblib
import io

import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss, accuracy_score, roc_auc_score, precision_score, recall_score

from itertools import combinations
import pickle
import warnings

import model_methods


# S3 and Athena details
bucket_name = "group3-project-bucket"
database_name = "group_project_db"
table_name = "hospital_readmissions"
s3_output = f"s3://{bucket_name}/athena-results/"
region = "us-east-1"
s3_client = boto3.client("s3", region_name=region)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %% [markdown]
# ## Find the latest feature store to generate a new model!

# %%
glue_client = boto3.client("glue")

# List databases in AWS Glue
response = glue_client.get_databases()
print("\nAvailable Databases in Glue:")
for db in response["DatabaseList"]:
    print(f"- {db['Name']}")

# List tables in the `sagemaker_featurestore` database (if it exists)
database_name = "sagemaker_featurestore"

try:
    response = glue_client.get_tables(DatabaseName=database_name)
    print(f"\nTables in `{database_name}` database:")
    for table in response["TableList"]:
        print(f"- {table['Name']}")
except glue_client.exceptions.EntityNotFoundException:
    print(f"\nDatabase `{database_name}` not found in Glue.")
# Out:
# Available Databases in Glue:
# - default
# - group_project_db
# - sagemaker_featurestore
#
# Tables in `sagemaker_featurestore` database:
# - hospital_readmissions_features_1740354579

# %% [markdown]
# Query Athenta Tables for Data Splitting

# %%
# Query the feature store in Athena

latest_table = response["TableList"][-1]
query = f"""
SELECT * 
FROM "sagemaker_featurestore"."{latest_table["Name"]}"
"""

# Connect to Athena
connection = connect(
    s3_staging_dir=f"s3://{bucket_name}/athena-results/",
    region_name="us-east-1"
)

# Retrieve all feature data
df = pd.read_sql(query, connection)
# Out:
# /tmp/ipykernel_2583/530253379.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)

# %%
df = df.drop(columns=["event_time", "write_time", "api_invocation_time", "is_deleted"])
display(df.head())


print("Base Features: ", len(df.columns))
print("Data Samples: ", len(df))

categorical_columns, num_cats = model_methods.get_categorical_columns_from_s3(bucket_name, s3_client)
print("Categorical columns: ", categorical_columns)
print("Num classes per category: ", num_cats)
# Out:
#    age  time_in_hospital  n_lab_procedures  n_procedures  n_medications  \
# 0    3                 6                47             3             24
# 1    3                 3                60             0             11
# 2    3                 4                79             1             11
# 3    3                 6                65             2             29
# 4    3                 1                 1             4             14
#
#    n_outpatient  n_inpatient  n_emergency  medical_specialty  diag_1  diag_2  \
# 0             0            1            0                  1       0       6
# 1             1            0            2                  4       6       0
# 2             1            1            1                  5       6       2
# 3             0            6            0                  4       7       7
# 4             0            0            0                  2       0       0
#
#    diag_3  glucose_test  a1ctest  change  diabetes_med  readmitted
# 0       6             1        1       1             1           1
# 1       6             1        1       0             0           0
# 2       6             1        1       0             1           1
# 3       0             0        1       0             1           0
# 4       0             1        1       0             1           1
# Base Features:  17
# Data Samples:  25000
# Identified categorical columns: ['glucose_test', 'A1Ctest', 'age', 'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'change', 'diabetes_med', 'readmitted']
# Category counts per categorical column: {'glucose_test': 3, 'A1Ctest': 3, 'age': 6, 'medical_specialty': 7, 'diag_1': 8, 'diag_2': 8, 'diag_3': 8, 'change': 2, 'diabetes_med': 2, 'readmitted': 2}
# Categorical columns:  ['glucose_test', 'A1Ctest', 'age', 'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'change', 'diabetes_med', 'readmitted']
# Num classes per category:  {'glucose_test': 3, 'A1Ctest': 3, 'age': 6, 'medical_specialty': 7, 'diag_1': 8, 'diag_2': 8, 'diag_3': 8, 'change': 2, 'diabetes_med': 2, 'readmitted': 2}

# %% [markdown]
# Train an XGB model raw, use SHAP to visual feature importance.

# %%
# Split data into train (50%), test (10%), production (40%)
train_df, temp_df = train_test_split(df, test_size=0.5, random_state=42)
test_df, prod_df = train_test_split(temp_df, test_size=0.8, random_state=42)

# Separate features and target variable
target_column = "readmitted"
X_train = train_df.drop(columns=[target_column])
y_train = train_df[target_column]
X_test = test_df.drop(columns=[target_column])
y_test = test_df[target_column]

# Train XGBoost model on production dataset
dmatrix_train = xgb.DMatrix(X_train, label=y_train)
params = {
    "objective": "binary:logistic",
    "eval_metric": "logloss",
    "seed": 42
}
model = xgb.train(params, dmatrix_train, num_boost_round=100)

def eval_model(model, X_test, y_test):
    """
    Evaluates the XGBoost model and returns evaluation metrics.
    Ensures all relevant metrics are logged for the model card.
    """
    # Convert test data into DMatrix
    dmatrix_test = xgb.DMatrix(X_test, label=y_test, enable_categorical=True)
    
    # Make predictions
    y_pred_proba = model.predict(dmatrix_test)
    y_pred = (y_pred_proba >= 0.5).astype(int)  # Convert probabilities to binary predictions
    
    # Compute evaluation metrics
    test_log_loss = log_loss(y_test, y_pred_proba)
    test_accuracy = accuracy_score(y_test, y_pred)
    test_auc = roc_auc_score(y_test, y_pred_proba)
    test_precision = precision_score(y_test, y_pred)
    test_recall = recall_score(y_test, y_pred)

    # Print evaluation metrics
    print(f"✅ Test Log Loss: {test_log_loss:.4f}")
    print(f"✅ Test Accuracy: {test_accuracy:.4f}")
    print(f"✅ Test AUC: {test_auc:.4f}")
    print(f"✅ Test Precision: {test_precision:.4f}")
    print(f"✅ Test Recall: {test_recall:.4f}")

    return test_accuracy, test_auc, test_precision, test_recall


eval_model(model, X_test, y_test)
# Out:
# ✅ Test Log Loss: 0.6887
# ✅ Test Accuracy: 0.5968
# ✅ Test AUC: 0.6283
# ✅ Test Precision: 0.5872
# ✅ Test Recall: 0.5172
# (0.5968, 0.6283117781117484, 0.5872259294566253, 0.5172124265323258)

# %% [markdown]
# Extract Important Features from XGBoost Model.. create interacting features from statistitically most important features.

# %%
X_train_final, X_test_final = model_methods.shap_feature_engineering(model, X_train, X_test, bucket_name, s3_client)
display(X_train_final.head())
display(X_test_final.head())

print(X_train_final.dtypes)
# Out:
# Identified categorical columns: ['glucose_test', 'A1Ctest', 'age', 'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'change', 'diabetes_med', 'readmitted']
# Category counts per categorical column: {'glucose_test': 3, 'A1Ctest': 3, 'age': 6, 'medical_specialty': 7, 'diag_1': 8, 'diag_2': 8, 'diag_3': 8, 'change': 2, 'diabetes_med': 2, 'readmitted': 2}
#  95%|=================== | 2376/2500 [00:11<00:00]
# Top Features: ['n_inpatient', 'n_lab_procedures', 'n_medications', 'time_in_hospital', 'diag_1', 'n_emergency', 'n_outpatient', 'age', 'diag_2', 'n_procedures', 'diag_3', 'medical_specialty', 'diabetes_med', 'a1ctest', 'glucose_test', 'change']
# Skipping interaction: n_inpatient × diag_1 (Categorical × Numeric)
# Skipping interaction: n_lab_procedures × diag_1 (Categorical × Numeric)
# Skipping interaction: n_medications × diag_1 (Categorical × Numeric)
# Skipping interaction: time_in_hospital × diag_1 (Categorical × Numeric)
# Interaction features saved to s3://group3-project-bucket/config/interaction_features.json
#        n_inpatient  n_lab_procedures  n_medications  time_in_hospital  diag_1  \
# 12204            1                55             23                 7       2
# 2655             0                49             30                 4       5
# 9592             1                35             21                 3       6
# 18228            6                56             15                10       0
# 18105            2                82             31                 8       7
#
#        n_emergency  n_outpatient  age  diag_2  n_procedures  ...  \
# 12204            0             2    3       7             1  ...
# 2655             0             0    2       6             4  ...
# 9592             0             3    1       0             1  ...
# 18228            1             0    4       0             0  ...
# 18105            0             0    4       0             1  ...
#
#        diabetes_med  a1ctest  glucose_test  change  \
# 12204             1        1             1       0
# 2655              1        1             1       1
# 9592              1        1             1       1
# 18228             0        0             1       0
# 18105             1        1             1       0
#
#        n_inpatient_x_n_lab_procedures  n_inpatient_x_n_medications  \
# 12204                              55                           23
# 2655                                0                            0
# 9592                               35                           21
# 18228                             336                           90
# 18105                             164                           62
#
#        n_inpatient_x_time_in_hospital  n_lab_procedures_x_n_medications  \
# 12204                               7                              1265
# 2655                                0                              1470
# 9592                                3                               735
# 18228                              60                               840
# 18105                              16                              2542
#
#        n_lab_procedures_x_time_in_hospital  n_medications_x_time_in_hospital
# 12204                                  385                               161
# 2655                                   196                               120
# 9592                                   105                                63
# 18228                                  560                               150
# 18105                                  656                               248
#
# [5 rows x 22 columns]
#       n_inpatient  n_lab_procedures  n_medications  time_in_hospital  diag_1  \
# 7198            0                57              8                 3       1
# 4580            0                54              6                 2       0
# 4278            2                51              7                11       6
# 1837            0                44             11                 3       2
# 9770            1                22             19                 4       1
#
#       n_emergency  n_outpatient  age  diag_2  n_procedures  ...  diabetes_med  \
# 7198            0             0    0       6             0  ...             1
# 4580            0             0    1       0             2  ...             1
# 4278            0             0    1       7             0  ...             0
# 1837            0             0    2       2             2  ...             0
# 9770            0             1    1       0             1  ...             1
#
#       a1ctest  glucose_test  change  n_inpatient_x_n_lab_procedures  \
# 7198        0             1       1                               0
# 4580        1             1       0                               0
# 4278        1             1       0                             102
# 1837        1             1       0                               0
# 9770        1             1       1                              22
#
#       n_inpatient_x_n_medications  n_inpatient_x_time_in_hospital  \
# 7198                            0                               0
# 4580                            0                               0
# 4278                           14                              22
# 1837                            0                               0
# 9770                           19                               4
#
#       n_lab_procedures_x_n_medications  n_lab_procedures_x_time_in_hospital  \
# 7198                               456                                  171
# 4580                               324                                  108
# 4278                               357                                  561
# 1837                               484                                  132
# 9770                               418                                   88
#
#       n_medications_x_time_in_hospital
# 7198                                24
# 4580                                12
# 4278                                77
# 1837                                33
# 9770                                76
#
# [5 rows x 22 columns]
# n_inpatient                            int64
# n_lab_procedures                       int64
# n_medications                          int64
# time_in_hospital                       int64
# diag_1                                 int64
# n_emergency                            int64
# n_outpatient                           int64
# age                                    int64
# diag_2                                 int64
# n_procedures                           int64
# diag_3                                 int64
# medical_specialty                      int64
# diabetes_med                           int64
# a1ctest                                int64
# glucose_test                           int64
# change                                 int64
# n_inpatient_x_n_lab_procedures         int64
# n_inpatient_x_n_medications            int64
# n_inpatient_x_time_in_hospital         int64
# n_lab_procedures_x_n_medications       int64
# n_lab_procedures_x_time_in_hospital    int64
# n_medications_x_time_in_hospital       int64
# dtype: object

# %% [markdown]
# ## Save Production Data to an s3 bucket for Later

# %%
X_prod = prod_df.drop(columns=[target_column])
y_prod = prod_df[target_column]

X_prod_final = model_methods.apply_interaction_features(X_prod, bucket_name, s3_client)
print(X_prod_final.columns)
# Out:
# Index(['age', 'time_in_hospital', 'n_lab_procedures', 'n_procedures',
#        'n_medications', 'n_outpatient', 'n_inpatient', 'n_emergency',
#        'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'glucose_test',
#        'a1ctest', 'change', 'diabetes_med', 'n_inpatient_x_n_lab_procedures',
#        'n_inpatient_x_n_medications', 'n_inpatient_x_time_in_hospital',
#        'n_lab_procedures_x_n_medications',
#        'n_lab_procedures_x_time_in_hospital',
#        'n_medications_x_time_in_hospital'],
#       dtype='object')

# %%
# Define S3 bucket and file path
def save_to_prod(df, name):
    s3_filename = f"production_data/{name}.csv"
    s3_uri = f"s3://{bucket_name}/{s3_filename}"
    
    # Convert DataFrame to CSV in memory
    csv_buffer = io.StringIO()
    df.to_csv(csv_buffer, index=False)
    
    # Upload CSV file to S3
    s3_client.put_object(
        Bucket=bucket_name,
        Key=s3_filename,
        Body=csv_buffer.getvalue()
    )
    
    print(f"Data saved to S3: {s3_uri}")

save_to_prod(X_prod_final, "X_prod_final")
save_to_prod(y_prod, "y_prod")
save_to_prod(X_train_final, "X_train_final")
save_to_prod(y_train, "y_train")
# Out:
# Data saved to S3: s3://group3-project-bucket/production_data/X_prod_final.csv
# Data saved to S3: s3://group3-project-bucket/production_data/y_prod.csv
# Data saved to S3: s3://group3-project-bucket/production_data/X_train_final.csv
# Data saved to S3: s3://group3-project-bucket/production_data/y_train.csv

# %% [markdown]
# Bayesian Optimization Procedure to find best XGB model

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /opt/conda/lib/python3.11/site-packages (4.2.0)
# Requirement already satisfied: alembic>=1.5.0 in /opt/conda/lib/python3.11/site-packages (from optuna) (1.14.1)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.11/site-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /opt/conda/lib/python3.11/site-packages (from optuna) (2.0.38)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.11/site-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (1.3.9)
# Requirement already satisfied: typing-extensions>=4 in /opt/conda/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/conda/lib/python3.11/site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)

# %%
import optuna
from sklearn.metrics import roc_auc_score

def xgb_objective(trial):
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_child_weight': trial.suggest_float('min_child_weight', 1, 10),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 1.0),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'seed': 42
    }
    
    dtrain = xgb.DMatrix(X_train_final, label=y_train, enable_categorical=True)
    dtest = xgb.DMatrix(X_test_final, label=y_test, enable_categorical=True)
    model = xgb.train(params, dtrain, num_boost_round=100)
    preds = model.predict(dtest)
    
    return roc_auc_score(y_test, preds)

study = optuna.create_study(direction="maximize")
study.optimize(xgb_objective, n_trials=1000)

best_params = study.best_params
best_params['max_depth'] = int(best_params['max_depth'])
# Out:
# [I 2025-02-27 03:28:33,411] A new study created in memory with name: no-name-4a265da1-3487-4312-8e62-7b4c92bb7d51
# [I 2025-02-27 03:28:33,660] Trial 0 finished with value: 0.6374547070946538 and parameters: {'learning_rate': 0.27677552343710593, 'max_depth': 6, 'min_child_weight': 6.505729319417778, 'colsample_bytree': 0.3133836323070009, 'subsample': 0.7110248445903466}. Best is trial 0 with value: 0.6374547070946538.
# [I 2025-02-27 03:28:33,926] Trial 1 finished with value: 0.6387228122299985 and parameters: {'learning_rate': 0.16394787146820755, 'max_depth': 4, 'min_child_weight': 1.8150430963299462, 'colsample_bytree': 0.8926730493264219, 'subsample': 0.8771257172851341}. Best is trial 1 with value: 0.6387228122299985.
# [I 2025-02-27 03:28:34,318] Trial 2 finished with value: 0.621358046309891 and parameters: {'learning_rate': 0.22475412754838334, 'max_depth': 8, 'min_child_weight': 5.195925751790097, 'colsample_bytree': 0.8061995058551319, 'subsample': 0.8857014746066882}. Best is trial 1 with value: 0.6387228122299985.
# [I 2025-02-27 03:28:34,652] Trial 3 finished with value: 0.6427131420463766 and parameters: {'learning_rate': 0.07551853034026122, 'max_depth': 6, 'min_child_weight': 3.2786601986503783, 'colsample_bytree': 0.9343892733351791, 'subsample': 0.860442808767446}. Best is trial 3 with value: 0.6427131420463766.
# [I 2025-02-27 03:28:35,081] Trial 4 finished with value: 0.6375842757528932 and parameters: {'learning_rate': 0.04934308597770486, 'max_depth': 9, 'min_child_weight': 5.362779497553906, 'colsample_bytree': 0.6202577135977404, 'subsample': 0.8940132521661351}. Best is trial 3 with value: 0.6427131420463766.
# [I 2025-02-27 03:28:35,639] Trial 5 finished with value: 0.6386490478948621 and parameters: {'learning_rate': 0.037245779659477854, 'max_depth': 9, 'min_child_weight': 2.4479015216695834, 'colsample_bytree': 0.5600182583774216, 'subsample': 0.9240243791697141}. Best is trial 3 with value: 0.6427131420463766.
# [I 2025-02-27 03:28:35,868] Trial 6 finished with value: 0.6403260640184629 and parameters: {'learning_rate': 0.0431471833823298, 'max_depth': 3, 'min_child_weight': 6.857944569958519, 'colsample_bytree': 0.8850466912431876, 'subsample': 0.765865586119541}. Best is trial 3 with value: 0.6427131420463766.
# [I 2025-02-27 03:28:36,191] Trial 7 finished with value: 0.6368376523955128 and parameters: {'learning_rate': 0.049655407483417, 'max_depth': 6, 'min_child_weight': 5.2330398440663055, 'colsample_bytree': 0.8680486254482644, 'subsample': 0.7563632933429107}. Best is trial 3 with value: 0.6427131420463766.
# [I 2025-02-27 03:28:36,476] Trial 8 finished with value: 0.6403372890259836 and parameters: {'learning_rate': 0.13645584689080203, 'max_depth': 4, 'min_child_weight': 7.79319389055712, 'colsample_bytree': 0.6372833577573767, 'subsample': 0.7132438901879268}. Best is trial 3 with value: 0.6427131420463766.
# [I 2025-02-27 03:28:36,970] Trial 9 finished with value: 0.6264381639992842 and parameters: {'learning_rate': 0.13537739015441375, 'max_depth': 10, 'min_child_weight': 4.514341357013947, 'colsample_bytree': 0.5511067860638701, 'subsample': 0.7742482777052102}. Best is trial 3 with value: 0.6427131420463766.
# [I 2025-02-27 03:28:37,408] Trial 10 finished with value: 0.6342956692638126 and parameters: {'learning_rate': 0.1071031300570345, 'max_depth': 7, 'min_child_weight': 9.43801009022627, 'colsample_bytree': 0.9868819906328743, 'subsample': 0.6279731264889674}. Best is trial 3 with value: 0.6427131420463766.
# [I 2025-02-27 03:28:37,708] Trial 11 finished with value: 0.6343816207499716 and parameters: {'learning_rate': 0.10623261932373598, 'max_depth': 5, 'min_child_weight': 9.399448100729334, 'colsample_bytree': 0.7276933503467142, 'subsample': 0.5677568740432464}. Best is trial 3 with value: 0.6427131420463766.
# [I 2025-02-27 03:28:37,976] Trial 12 finished with value: 0.6354605043299664 and parameters: {'learning_rate': 0.17924175801137548, 'max_depth': 4, 'min_child_weight': 3.559850946516642, 'colsample_bytree': 0.44591418594316407, 'subsample': 0.9930418358665729}. Best is trial 3 with value: 0.6427131420463766.
# [I 2025-02-27 03:28:38,296] Trial 13 finished with value: 0.6465726203465127 and parameters: {'learning_rate': 0.09250069792290189, 'max_depth': 5, 'min_child_weight': 7.578540751003054, 'colsample_bytree': 0.7093258952448083, 'subsample': 0.6717526215586218}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:38,779] Trial 14 finished with value: 0.6402673732648544 and parameters: {'learning_rate': 0.08496742145951577, 'max_depth': 7, 'min_child_weight': 1.0394921610826016, 'colsample_bytree': 0.9976419783087036, 'subsample': 0.6317534490342895}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:39,131] Trial 15 finished with value: 0.6391188946382309 and parameters: {'learning_rate': 0.014646971364931288, 'max_depth': 5, 'min_child_weight': 3.5789322046454535, 'colsample_bytree': 0.7305869851705686, 'subsample': 0.8118272159244515}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:39,546] Trial 16 finished with value: 0.6400929045765318 and parameters: {'learning_rate': 0.07530188502384343, 'max_depth': 5, 'min_child_weight': 7.775892057231798, 'colsample_bytree': 0.7401462029351975, 'subsample': 0.5108860079262716}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:39,818] Trial 17 finished with value: 0.6412134810416037 and parameters: {'learning_rate': 0.19629616024152516, 'max_depth': 3, 'min_child_weight': 3.5863576061664517, 'colsample_bytree': 0.4497753275668669, 'subsample': 0.6679454430067167}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:40,155] Trial 18 finished with value: 0.6401108645885649 and parameters: {'learning_rate': 0.08856269019005916, 'max_depth': 6, 'min_child_weight': 8.38592266794279, 'colsample_bytree': 0.8005839349860846, 'subsample': 0.8093301377910428}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:40,628] Trial 19 finished with value: 0.6363020591795225 and parameters: {'learning_rate': 0.12777221910696274, 'max_depth': 8, 'min_child_weight': 6.4277723936479045, 'colsample_bytree': 0.9447251861853023, 'subsample': 0.986561737861355}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:41,044] Trial 20 finished with value: 0.6214465635120547 and parameters: {'learning_rate': 0.23849076529037128, 'max_depth': 7, 'min_child_weight': 2.3760866849142053, 'colsample_bytree': 0.8202689695055564, 'subsample': 0.8387106406104633}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:41,287] Trial 21 finished with value: 0.6414014197389513 and parameters: {'learning_rate': 0.1991130931499108, 'max_depth': 3, 'min_child_weight': 3.873868799121229, 'colsample_bytree': 0.4095682528875497, 'subsample': 0.6664917884643836}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:41,517] Trial 22 finished with value: 0.6356567816043294 and parameters: {'learning_rate': 0.19443576656544181, 'max_depth': 3, 'min_child_weight': 4.287886404709148, 'colsample_bytree': 0.3218024298507775, 'subsample': 0.6784283057889271}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:41,904] Trial 23 finished with value: 0.6208622216919744 and parameters: {'learning_rate': 0.241561038903496, 'max_depth': 5, 'min_child_weight': 2.8575558501894758, 'colsample_bytree': 0.4027644293366516, 'subsample': 0.5974444732040279}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:42,148] Trial 24 finished with value: 0.639347243362653 and parameters: {'learning_rate': 0.15592600393580483, 'max_depth': 4, 'min_child_weight': 4.3418425124126205, 'colsample_bytree': 0.5468372877363059, 'subsample': 0.7095613984243715}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:42,457] Trial 25 finished with value: 0.6360878218931264 and parameters: {'learning_rate': 0.11155106709726986, 'max_depth': 6, 'min_child_weight': 5.877925557098018, 'colsample_bytree': 0.6923017713908924, 'subsample': 0.5277678820664905}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:42,800] Trial 26 finished with value: 0.641704174227511 and parameters: {'learning_rate': 0.07174423592183374, 'max_depth': 5, 'min_child_weight': 2.978282596856853, 'colsample_bytree': 0.4759058012132199, 'subsample': 0.630223671626331}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:43,106] Trial 27 finished with value: 0.6433988296486445 and parameters: {'learning_rate': 0.06677810701891362, 'max_depth': 5, 'min_child_weight': 1.2225178413298978, 'colsample_bytree': 0.4910645507985363, 'subsample': 0.6014069779721668}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:43,458] Trial 28 finished with value: 0.6399402444742495 and parameters: {'learning_rate': 0.06709276821641745, 'max_depth': 6, 'min_child_weight': 1.544921273962497, 'colsample_bytree': 0.579287262177987, 'subsample': 0.5581773966748447}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:44,056] Trial 29 finished with value: 0.6402737875548662 and parameters: {'learning_rate': 0.015814798196804022, 'max_depth': 7, 'min_child_weight': 1.1445718965608993, 'colsample_bytree': 0.5014900124402129, 'subsample': 0.7277269737043849}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:44,335] Trial 30 finished with value: 0.6421348938018074 and parameters: {'learning_rate': 0.0953061170570482, 'max_depth': 5, 'min_child_weight': 2.102750703005378, 'colsample_bytree': 0.32624307282403614, 'subsample': 0.6019675826128296}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:44,605] Trial 31 finished with value: 0.6183555171553393 and parameters: {'learning_rate': 0.29782865148308524, 'max_depth': 5, 'min_child_weight': 2.1225292211739304, 'colsample_bytree': 0.30774998809571075, 'subsample': 0.5799077109152299}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:44,866] Trial 32 finished with value: 0.6412949425247543 and parameters: {'learning_rate': 0.10025308064225252, 'max_depth': 4, 'min_child_weight': 1.619179430034265, 'colsample_bytree': 0.36229802980947723, 'subsample': 0.5445534432250663}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:45,206] Trial 33 finished with value: 0.6433436667545425 and parameters: {'learning_rate': 0.06280376384609226, 'max_depth': 6, 'min_child_weight': 2.673373002430619, 'colsample_bytree': 0.5058194435259612, 'subsample': 0.5960679958524093}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:45,575] Trial 34 finished with value: 0.637162215470113 and parameters: {'learning_rate': 0.060291568982125884, 'max_depth': 6, 'min_child_weight': 1.6000219442879915, 'colsample_bytree': 0.6248139094912373, 'subsample': 0.649101008417931}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:45,960] Trial 35 finished with value: 0.6400425523999387 and parameters: {'learning_rate': 0.029164348237785867, 'max_depth': 6, 'min_child_weight': 2.791005134051787, 'colsample_bytree': 0.5088896373487534, 'subsample': 0.688825961874959}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:46,407] Trial 36 finished with value: 0.6416499734769108 and parameters: {'learning_rate': 0.05467724246896791, 'max_depth': 8, 'min_child_weight': 4.7932893617428824, 'colsample_bytree': 0.6768939828052578, 'subsample': 0.942279715637869}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:46,738] Trial 37 finished with value: 0.6450569236167103 and parameters: {'learning_rate': 0.12288898261334312, 'max_depth': 4, 'min_child_weight': 5.793857378423207, 'colsample_bytree': 0.5930687521390191, 'subsample': 0.8587258258759166}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:47,020] Trial 38 finished with value: 0.6416907042184861 and parameters: {'learning_rate': 0.1157781308198576, 'max_depth': 4, 'min_child_weight': 6.023223038201542, 'colsample_bytree': 0.5900196484868265, 'subsample': 0.5949051996807777}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:47,250] Trial 39 finished with value: 0.6313778087374176 and parameters: {'learning_rate': 0.14491749314066993, 'max_depth': 4, 'min_child_weight': 7.195228926225738, 'colsample_bytree': 0.5098860536834326, 'subsample': 0.5017107459390401}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:47,497] Trial 40 finished with value: 0.6392551983009829 and parameters: {'learning_rate': 0.12274987047177016, 'max_depth': 5, 'min_child_weight': 8.370476175821482, 'colsample_bytree': 0.6594563363516006, 'subsample': 0.9125456014159261}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:47,776] Trial 41 finished with value: 0.6443122245463333 and parameters: {'learning_rate': 0.08115773182809924, 'max_depth': 6, 'min_child_weight': 5.775418911349979, 'colsample_bytree': 0.53642457381657, 'subsample': 0.8500462106600112}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:48,189] Trial 42 finished with value: 0.6415268191086831 and parameters: {'learning_rate': 0.03531268311849377, 'max_depth': 7, 'min_child_weight': 5.557040904318708, 'colsample_bytree': 0.6134674587809246, 'subsample': 0.863097265151143}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:48,515] Trial 43 finished with value: 0.6424594568764075 and parameters: {'learning_rate': 0.08530077725069246, 'max_depth': 6, 'min_child_weight': 6.899770226309389, 'colsample_bytree': 0.5470736582223128, 'subsample': 0.7880914980044099}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:48,818] Trial 44 finished with value: 0.6409088022660404 and parameters: {'learning_rate': 0.05903585731381655, 'max_depth': 4, 'min_child_weight': 6.209395019186386, 'colsample_bytree': 0.592187921248246, 'subsample': 0.8387014871249486}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:49,112] Trial 45 finished with value: 0.6394001612552509 and parameters: {'learning_rate': 0.04359975032555451, 'max_depth': 5, 'min_child_weight': 5.004751177191057, 'colsample_bytree': 0.5331144518341409, 'subsample': 0.7397999588061946}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:49,349] Trial 46 finished with value: 0.6464879517183564 and parameters: {'learning_rate': 0.08158716534242938, 'max_depth': 4, 'min_child_weight': 7.699838922623002, 'colsample_bytree': 0.47282374740663735, 'subsample': 0.8936807300685554}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:49,610] Trial 47 finished with value: 0.6442410259272016 and parameters: {'learning_rate': 0.08344010070187904, 'max_depth': 4, 'min_child_weight': 7.5592326773636636, 'colsample_bytree': 0.45639609539854875, 'subsample': 0.9528058863832146}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:49,873] Trial 48 finished with value: 0.6424376482903673 and parameters: {'learning_rate': 0.13847979648113362, 'max_depth': 3, 'min_child_weight': 7.46755626513866, 'colsample_bytree': 0.4556747632223075, 'subsample': 0.9561408348097715}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:50,143] Trial 49 finished with value: 0.6457098983399177 and parameters: {'learning_rate': 0.16625025910576707, 'max_depth': 4, 'min_child_weight': 8.656745655847157, 'colsample_bytree': 0.38350233626023655, 'subsample': 0.8964911592620335}. Best is trial 13 with value: 0.6465726203465127.
# [I 2025-02-27 03:28:50,382] Trial 50 finished with value: 0.6468413790980097 and parameters: {'learning_rate': 0.1610928775266195, 'max_depth': 3, 'min_child_weight': 9.974486901843015, 'colsample_bytree': 0.39739356767497946, 'subsample': 0.8907846191512512}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:50,634] Trial 51 finished with value: 0.641776655704645 and parameters: {'learning_rate': 0.17093004952115456, 'max_depth': 3, 'min_child_weight': 9.905878418143999, 'colsample_bytree': 0.40688059971861346, 'subsample': 0.8928824234765669}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:50,874] Trial 52 finished with value: 0.6450036850096117 and parameters: {'learning_rate': 0.15088963009123282, 'max_depth': 3, 'min_child_weight': 8.644251129179395, 'colsample_bytree': 0.35785557100422083, 'subsample': 0.9131192652665141}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:51,161] Trial 53 finished with value: 0.6441307001389978 and parameters: {'learning_rate': 0.15494664514349168, 'max_depth': 3, 'min_child_weight': 8.67545216367303, 'colsample_bytree': 0.3604880214036516, 'subsample': 0.9114079479424569}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:51,366] Trial 54 finished with value: 0.6437102434287203 and parameters: {'learning_rate': 0.18302969336181493, 'max_depth': 3, 'min_child_weight': 8.975717854330664, 'colsample_bytree': 0.36306486228336965, 'subsample': 0.880141120454003}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:51,625] Trial 55 finished with value: 0.6434802911317951 and parameters: {'learning_rate': 0.2157652973039099, 'max_depth': 4, 'min_child_weight': 8.179624536953801, 'colsample_bytree': 0.41495132453218414, 'subsample': 0.926691405545627}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:51,895] Trial 56 finished with value: 0.6432990874389599 and parameters: {'learning_rate': 0.14915501564574515, 'max_depth': 3, 'min_child_weight': 9.171732661459913, 'colsample_bytree': 0.3842951995487117, 'subsample': 0.9714557363426922}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:52,142] Trial 57 finished with value: 0.6411891067395588 and parameters: {'learning_rate': 0.16596569596832245, 'max_depth': 4, 'min_child_weight': 9.982622503780139, 'colsample_bytree': 0.4296865421248802, 'subsample': 0.8702966052052789}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:52,358] Trial 58 finished with value: 0.6425287312085357 and parameters: {'learning_rate': 0.12809428382957294, 'max_depth': 3, 'min_child_weight': 8.06447055593616, 'colsample_bytree': 0.3385775444594675, 'subsample': 0.8234481683985728}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:52,589] Trial 59 finished with value: 0.6384675234875264 and parameters: {'learning_rate': 0.18671618778378843, 'max_depth': 4, 'min_child_weight': 9.663110369398124, 'colsample_bytree': 0.3862333868359561, 'subsample': 0.8988028364078307}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:52,988] Trial 60 finished with value: 0.6201977012467456 and parameters: {'learning_rate': 0.21159306128960503, 'max_depth': 10, 'min_child_weight': 8.759895329710885, 'colsample_bytree': 0.7046453192839958, 'subsample': 0.9244942015794431}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:53,255] Trial 61 finished with value: 0.6436156326510454 and parameters: {'learning_rate': 0.1724871058283623, 'max_depth': 4, 'min_child_weight': 6.899409955277456, 'colsample_bytree': 0.4764554533063962, 'subsample': 0.8400098581652898}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:53,481] Trial 62 finished with value: 0.6443458995688955 and parameters: {'learning_rate': 0.09987831372214998, 'max_depth': 3, 'min_child_weight': 9.405098161652312, 'colsample_bytree': 0.759145928351736, 'subsample': 0.7775066635217079}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:53,692] Trial 63 finished with value: 0.6435380197419018 and parameters: {'learning_rate': 0.11566156332342456, 'max_depth': 3, 'min_child_weight': 9.437844742888231, 'colsample_bytree': 0.8035539689754505, 'subsample': 0.7788246367026279}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:53,962] Trial 64 finished with value: 0.6414585069200568 and parameters: {'learning_rate': 0.15998542367337085, 'max_depth': 3, 'min_child_weight': 8.989399009739863, 'colsample_bytree': 0.7450641487483712, 'subsample': 0.7947683049358572}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:54,243] Trial 65 finished with value: 0.6434578411167535 and parameters: {'learning_rate': 0.10233148012661802, 'max_depth': 3, 'min_child_weight': 8.617653393877223, 'colsample_bytree': 0.7707102135794079, 'subsample': 0.8845168274585106}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:54,511] Trial 66 finished with value: 0.6406073306354829 and parameters: {'learning_rate': 0.12666643717273474, 'max_depth': 4, 'min_child_weight': 8.015785250416549, 'colsample_bytree': 0.8337294426483138, 'subsample': 0.7610943342606532}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:54,852] Trial 67 finished with value: 0.6432554702668793 and parameters: {'learning_rate': 0.09510220528750969, 'max_depth': 3, 'min_child_weight': 9.217538700625548, 'colsample_bytree': 0.7678029164593234, 'subsample': 0.9381750200933079}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:55,311] Trial 68 finished with value: 0.6366118693870954 and parameters: {'learning_rate': 0.13680036511380822, 'max_depth': 9, 'min_child_weight': 9.715312518476777, 'colsample_bytree': 0.3466036397013404, 'subsample': 0.9015499708213086}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:55,567] Trial 69 finished with value: 0.6428536149976363 and parameters: {'learning_rate': 0.14554645163464117, 'max_depth': 4, 'min_child_weight': 6.521101588051591, 'colsample_bytree': 0.30272123016303526, 'subsample': 0.811547803090251}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:55,789] Trial 70 finished with value: 0.6420547151766592 and parameters: {'learning_rate': 0.10944540299015419, 'max_depth': 3, 'min_child_weight': 8.523332848523888, 'colsample_bytree': 0.8583365886144283, 'subsample': 0.8534806813606999}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:56,102] Trial 71 finished with value: 0.6448590427698444 and parameters: {'learning_rate': 0.07674653269580482, 'max_depth': 5, 'min_child_weight': 7.747533107810021, 'colsample_bytree': 0.6501301813540483, 'subsample': 0.8507554094805851}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:56,419] Trial 72 finished with value: 0.640898860116522 and parameters: {'learning_rate': 0.09387640151926172, 'max_depth': 5, 'min_child_weight': 7.798092241595302, 'colsample_bytree': 0.6432441100662415, 'subsample': 0.8692144173342163}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:56,713] Trial 73 finished with value: 0.6400156123818888 and parameters: {'learning_rate': 0.07530507824864086, 'max_depth': 4, 'min_child_weight': 7.3690531350344015, 'colsample_bytree': 0.6652113782172346, 'subsample': 0.8301928277505927}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:57,043] Trial 74 finished with value: 0.6417651099826237 and parameters: {'learning_rate': 0.12078434075412037, 'max_depth': 5, 'min_child_weight': 7.81893104227953, 'colsample_bytree': 0.7235335264241587, 'subsample': 0.9108277017356043}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:57,317] Trial 75 finished with value: 0.6410229766282515 and parameters: {'learning_rate': 0.13502102597049342, 'max_depth': 4, 'min_child_weight': 8.237294745571383, 'colsample_bytree': 0.6975622469566233, 'subsample': 0.8820830832720037}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:57,560] Trial 76 finished with value: 0.6428927421667087 and parameters: {'learning_rate': 0.11077165935637888, 'max_depth': 3, 'min_child_weight': 9.120857529534609, 'colsample_bytree': 0.3881508098981444, 'subsample': 0.6999837992707372}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:57,835] Trial 77 finished with value: 0.6445938118778538 and parameters: {'learning_rate': 0.15353033827190715, 'max_depth': 4, 'min_child_weight': 8.867744526032793, 'colsample_bytree': 0.4358574846997004, 'subsample': 0.7407505444044542}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:58,094] Trial 78 finished with value: 0.6385265349556355 and parameters: {'learning_rate': 0.17435963229878368, 'max_depth': 5, 'min_child_weight': 8.925849071795573, 'colsample_bytree': 0.4333266033506316, 'subsample': 0.9766254170212496}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:58,355] Trial 79 finished with value: 0.6438407742304617 and parameters: {'learning_rate': 0.15339712325684504, 'max_depth': 4, 'min_child_weight': 7.071880449980506, 'colsample_bytree': 0.5727605062466267, 'subsample': 0.7405979861097148}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:58,613] Trial 80 finished with value: 0.6390473753045987 and parameters: {'learning_rate': 0.16200567928966364, 'max_depth': 5, 'min_child_weight': 8.487779053961717, 'colsample_bytree': 0.4670731462410087, 'subsample': 0.856653951898673}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:58,846] Trial 81 finished with value: 0.6418433643207684 and parameters: {'learning_rate': 0.1890761011111446, 'max_depth': 4, 'min_child_weight': 9.540766542055318, 'colsample_bytree': 0.6100762530070226, 'subsample': 0.7233040339813175}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:59,116] Trial 82 finished with value: 0.6433439874690431 and parameters: {'learning_rate': 0.09178077695285584, 'max_depth': 3, 'min_child_weight': 9.331754232194404, 'colsample_bytree': 0.7756850876097925, 'subsample': 0.6637908187864263}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:59,411] Trial 83 finished with value: 0.6436092183610334 and parameters: {'learning_rate': 0.10472519163767252, 'max_depth': 4, 'min_child_weight': 8.76292071578865, 'colsample_bytree': 0.6802577298488263, 'subsample': 0.798367208660419}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:59,668] Trial 84 finished with value: 0.6425438047900635 and parameters: {'learning_rate': 0.06977726765620995, 'max_depth': 3, 'min_child_weight': 6.684944704929529, 'colsample_bytree': 0.4366614881787984, 'subsample': 0.7710028301384854}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:28:59,929] Trial 85 finished with value: 0.6409094436950415 and parameters: {'learning_rate': 0.1304380512348718, 'max_depth': 4, 'min_child_weight': 7.595953228225495, 'colsample_bytree': 0.374556865550785, 'subsample': 0.82244708874641}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:29:00,195] Trial 86 finished with value: 0.64222822172148 and parameters: {'learning_rate': 0.08043061380901206, 'max_depth': 5, 'min_child_weight': 7.951991198256142, 'colsample_bytree': 0.4181706373117623, 'subsample': 0.890574155268198}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:29:00,440] Trial 87 finished with value: 0.6402792397013763 and parameters: {'learning_rate': 0.050433852531477426, 'max_depth': 3, 'min_child_weight': 9.760301880592188, 'colsample_bytree': 0.32899288370029317, 'subsample': 0.6490181972543555}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:29:00,759] Trial 88 finished with value: 0.6411442067094757 and parameters: {'learning_rate': 0.14181985402519282, 'max_depth': 4, 'min_child_weight': 8.28468520981995, 'colsample_bytree': 0.7153189123004987, 'subsample': 0.8707443122723914}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:29:01,036] Trial 89 finished with value: 0.6417388113935751 and parameters: {'learning_rate': 0.11837305706521713, 'max_depth': 3, 'min_child_weight': 7.195757869230889, 'colsample_bytree': 0.39928272121823566, 'subsample': 0.7490222802898353}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:29:01,404] Trial 90 finished with value: 0.6382994690892156 and parameters: {'learning_rate': 0.1651947883220908, 'max_depth': 5, 'min_child_weight': 9.372035756375071, 'colsample_bytree': 0.628883169882021, 'subsample': 0.9351098805817138}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:29:01,900] Trial 91 finished with value: 0.6445636647147982 and parameters: {'learning_rate': 0.08227177426147572, 'max_depth': 6, 'min_child_weight': 5.732284353105923, 'colsample_bytree': 0.6006054446067393, 'subsample': 0.848510025986164}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:29:02,375] Trial 92 finished with value: 0.6442480816462147 and parameters: {'learning_rate': 0.0979871723748248, 'max_depth': 6, 'min_child_weight': 5.445563258571483, 'colsample_bytree': 0.5242759598641379, 'subsample': 0.8433888775681039}. Best is trial 50 with value: 0.6468413790980097.
# [I 2025-02-27 03:29:02,736] Trial 93 finished with value: 0.6470459949493881 and parameters: {'learning_rate': 0.08542969943266869, 'max_depth': 5, 'min_child_weight': 6.278255210355598, 'colsample_bytree': 0.5653062351085247, 'subsample': 0.905709756925081}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:03,109] Trial 94 finished with value: 0.6428023006775414 and parameters: {'learning_rate': 0.07702020392449431, 'max_depth': 5, 'min_child_weight': 6.289543577768891, 'colsample_bytree': 0.6023645465399257, 'subsample': 0.9088020627834411}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:03,450] Trial 95 finished with value: 0.6432612431278901 and parameters: {'learning_rate': 0.08826382634010341, 'max_depth': 5, 'min_child_weight': 5.955913728548305, 'colsample_bytree': 0.5544254278245473, 'subsample': 0.9547777193692967}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:03,853] Trial 96 finished with value: 0.6435514897509267 and parameters: {'learning_rate': 0.06564011755964817, 'max_depth': 7, 'min_child_weight': 5.627819819783083, 'colsample_bytree': 0.641383757406656, 'subsample': 0.9259238264507147}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:04,358] Trial 97 finished with value: 0.6340839976934214 and parameters: {'learning_rate': 0.17691753094593032, 'max_depth': 6, 'min_child_weight': 5.697101833172854, 'colsample_bytree': 0.5751323741817274, 'subsample': 0.902872475659523}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:04,711] Trial 98 finished with value: 0.6410742909483463 and parameters: {'learning_rate': 0.07129419089108692, 'max_depth': 5, 'min_child_weight': 5.1563240729002295, 'colsample_bytree': 0.6590335523507087, 'subsample': 0.877487507696427}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:05,039] Trial 99 finished with value: 0.6448484591913248 and parameters: {'learning_rate': 0.05781829088882795, 'max_depth': 4, 'min_child_weight': 4.836512983044937, 'colsample_bytree': 0.4917874426188092, 'subsample': 0.9182183899026378}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:05,325] Trial 100 finished with value: 0.6433994710776456 and parameters: {'learning_rate': 0.05646206467248497, 'max_depth': 4, 'min_child_weight': 4.021455798166434, 'colsample_bytree': 0.4838981036398996, 'subsample': 0.9195353096279913}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:05,631] Trial 101 finished with value: 0.6415059726661445 and parameters: {'learning_rate': 0.08626326207081526, 'max_depth': 4, 'min_child_weight': 5.35751511256451, 'colsample_bytree': 0.5276756527076871, 'subsample': 0.8615842467484709}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:05,941] Trial 102 finished with value: 0.6391169703512273 and parameters: {'learning_rate': 0.1505194837659793, 'max_depth': 4, 'min_child_weight': 4.547069708843156, 'colsample_bytree': 0.5925290090867698, 'subsample': 0.888996853500785}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:06,265] Trial 103 finished with value: 0.6436169155090476 and parameters: {'learning_rate': 0.037451529070321746, 'max_depth': 5, 'min_child_weight': 5.170733084448157, 'colsample_bytree': 0.44634868455879423, 'subsample': 0.8996897909354642}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:06,558] Trial 104 finished with value: 0.6414876919396107 and parameters: {'learning_rate': 0.04918129265939506, 'max_depth': 4, 'min_child_weight': 4.7860513848649076, 'colsample_bytree': 0.4620889981417434, 'subsample': 0.8457044808232954}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:06,843] Trial 105 finished with value: 0.640000538800361 and parameters: {'learning_rate': 0.1573911599977311, 'max_depth': 5, 'min_child_weight': 6.219712902436134, 'colsample_bytree': 0.3536033196969896, 'subsample': 0.9432940604863755}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:07,105] Trial 106 finished with value: 0.6426534891492663 and parameters: {'learning_rate': 0.169187020257325, 'max_depth': 4, 'min_child_weight': 4.821498774083356, 'colsample_bytree': 0.49091312611342386, 'subsample': 0.8713675741027839}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:07,403] Trial 107 finished with value: 0.6308223312223905 and parameters: {'learning_rate': 0.2589213686979058, 'max_depth': 6, 'min_child_weight': 6.679258526685579, 'colsample_bytree': 0.5643000688970196, 'subsample': 0.9139876080824336}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:07,646] Trial 108 finished with value: 0.6423513760897077 and parameters: {'learning_rate': 0.06352306172801087, 'max_depth': 4, 'min_child_weight': 7.350463138572122, 'colsample_bytree': 0.4210811109512676, 'subsample': 0.9691740319191819}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:07,950] Trial 109 finished with value: 0.6380858732318209 and parameters: {'learning_rate': 0.20093127830470164, 'max_depth': 5, 'min_child_weight': 6.101761609720519, 'colsample_bytree': 0.3988991755960283, 'subsample': 0.9316661420531519}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:08,222] Trial 110 finished with value: 0.6402664111213525 and parameters: {'learning_rate': 0.0795448348687681, 'max_depth': 4, 'min_child_weight': 8.8378207332156, 'colsample_bytree': 0.3757128855225763, 'subsample': 0.8882412869128566}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:08,538] Trial 111 finished with value: 0.6442840016702812 and parameters: {'learning_rate': 0.1014934907304812, 'max_depth': 3, 'min_child_weight': 9.862035404532, 'colsample_bytree': 0.6266149736285651, 'subsample': 0.8300861154413972}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:08,816] Trial 112 finished with value: 0.6422262974344763 and parameters: {'learning_rate': 0.0917625054829367, 'max_depth': 3, 'min_child_weight': 5.803573582416382, 'colsample_bytree': 0.7462186926983728, 'subsample': 0.860742263961794}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:09,307] Trial 113 finished with value: 0.6365028264568937 and parameters: {'learning_rate': 0.10676256140870369, 'max_depth': 8, 'min_child_weight': 9.508014335504747, 'colsample_bytree': 0.6813802338091177, 'subsample': 0.9178446391687957}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:09,569] Trial 114 finished with value: 0.6397574372089114 and parameters: {'learning_rate': 0.07266207294737172, 'max_depth': 3, 'min_child_weight': 8.388194306727588, 'colsample_bytree': 0.5034609148511229, 'subsample': 0.6876655880742704}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:09,803] Trial 115 finished with value: 0.6435947862085067 and parameters: {'learning_rate': 0.0833802124711586, 'max_depth': 3, 'min_child_weight': 7.660908227132243, 'colsample_bytree': 0.5188060406563637, 'subsample': 0.7847944261852282}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:10,097] Trial 116 finished with value: 0.6431544451991925 and parameters: {'learning_rate': 0.11417008359415576, 'max_depth': 4, 'min_child_weight': 9.170033060955108, 'colsample_bytree': 0.6131756989002839, 'subsample': 0.7174464876618674}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:10,384] Trial 117 finished with value: 0.6397632100699222 and parameters: {'learning_rate': 0.14376061060616627, 'max_depth': 4, 'min_child_weight': 9.028165815425844, 'colsample_bytree': 0.7604566068866409, 'subsample': 0.6149020308939386}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:10,751] Trial 118 finished with value: 0.6336908017156943 and parameters: {'learning_rate': 0.18020124615213032, 'max_depth': 6, 'min_child_weight': 7.993483525132026, 'colsample_bytree': 0.7843783293160403, 'subsample': 0.9015740139298898}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:11,029] Trial 119 finished with value: 0.6426265491312164 and parameters: {'learning_rate': 0.13219526535787143, 'max_depth': 3, 'min_child_weight': 9.97341534521005, 'colsample_bytree': 0.5881916629408729, 'subsample': 0.8054423442703618}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:11,393] Trial 120 finished with value: 0.638700362214957 and parameters: {'learning_rate': 0.09931508823421484, 'max_depth': 4, 'min_child_weight': 8.598553656131218, 'colsample_bytree': 0.5420538420472328, 'subsample': 0.874159872363412}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:11,771] Trial 121 finished with value: 0.645718236916933 and parameters: {'learning_rate': 0.0825681509066425, 'max_depth': 6, 'min_child_weight': 5.855953255871672, 'colsample_bytree': 0.5630949226810301, 'subsample': 0.8494624033442232}. Best is trial 93 with value: 0.6470459949493881.
# [I 2025-02-27 03:29:12,133] Trial 122 finished with value: 0.6470549749554046 and parameters: {'learning_rate': 0.07759907531833586, 'max_depth': 6, 'min_child_weight': 5.365186566020773, 'colsample_bytree': 0.5682240613721897, 'subsample': 0.829965130242362}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:12,523] Trial 123 finished with value: 0.6450274178826556 and parameters: {'learning_rate': 0.07765502052982876, 'max_depth': 6, 'min_child_weight': 5.481913873421031, 'colsample_bytree': 0.5625899394993974, 'subsample': 0.8495674623997465}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:12,943] Trial 124 finished with value: 0.6454218967183851 and parameters: {'learning_rate': 0.06029948524039024, 'max_depth': 7, 'min_child_weight': 5.333324429941619, 'colsample_bytree': 0.5677233210158976, 'subsample': 0.8186366897475156}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:13,341] Trial 125 finished with value: 0.6400387038259316 and parameters: {'learning_rate': 0.024319111890894078, 'max_depth': 6, 'min_child_weight': 4.978572842195853, 'colsample_bytree': 0.5542105937764933, 'subsample': 0.8536333925803968}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:13,773] Trial 126 finished with value: 0.6417253413845501 and parameters: {'learning_rate': 0.05878686916740352, 'max_depth': 7, 'min_child_weight': 5.286218389554594, 'colsample_bytree': 0.5684071900731962, 'subsample': 0.8185475448389353}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:14,215] Trial 127 finished with value: 0.6373517577399634 and parameters: {'learning_rate': 0.05090314674813737, 'max_depth': 7, 'min_child_weight': 5.49960920952089, 'colsample_bytree': 0.541475254876596, 'subsample': 0.8314496255904257}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:14,680] Trial 128 finished with value: 0.6396474321352081 and parameters: {'learning_rate': 0.07105231060623396, 'max_depth': 7, 'min_child_weight': 5.949553450382648, 'colsample_bytree': 0.5830835601559327, 'subsample': 0.8807834171601221}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:15,039] Trial 129 finished with value: 0.6417805042786522 and parameters: {'learning_rate': 0.06458688429085024, 'max_depth': 6, 'min_child_weight': 4.580105727991759, 'colsample_bytree': 0.5625668080789654, 'subsample': 0.8641601185502911}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:15,519] Trial 130 finished with value: 0.6428484835656268 and parameters: {'learning_rate': 0.04487977869153438, 'max_depth': 7, 'min_child_weight': 4.9837612682398404, 'colsample_bytree': 0.5122012357287363, 'subsample': 0.8369713162284423}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:15,862] Trial 131 finished with value: 0.6414585069200568 and parameters: {'learning_rate': 0.08711998029080535, 'max_depth': 6, 'min_child_weight': 5.48434115679387, 'colsample_bytree': 0.4737457700214642, 'subsample': 0.8945352480380352}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:16,215] Trial 132 finished with value: 0.6439126142785944 and parameters: {'learning_rate': 0.07483480034527577, 'max_depth': 6, 'min_child_weight': 6.447846490210514, 'colsample_bytree': 0.5299270433163481, 'subsample': 0.8015113622189178}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:16,737] Trial 133 finished with value: 0.638131414690905 and parameters: {'learning_rate': 0.09191423496660875, 'max_depth': 8, 'min_child_weight': 4.164850958440821, 'colsample_bytree': 0.43735868750115914, 'subsample': 0.9450720738316688}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:17,120] Trial 134 finished with value: 0.6383398791162904 and parameters: {'learning_rate': 0.0785749503971539, 'max_depth': 7, 'min_child_weight': 5.192320333301231, 'colsample_bytree': 0.4964188401324781, 'subsample': 0.8183111869229613}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:17,465] Trial 135 finished with value: 0.6385643792667055 and parameters: {'learning_rate': 0.16109600197042634, 'max_depth': 5, 'min_child_weight': 8.181955558252678, 'colsample_bytree': 0.5530432820747562, 'subsample': 0.8524359230860676}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:17,811] Trial 136 finished with value: 0.6410710838033404 and parameters: {'learning_rate': 0.060128251766658286, 'max_depth': 5, 'min_child_weight': 6.09362045211183, 'colsample_bytree': 0.39359209784500354, 'subsample': 0.8875832715035262}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:18,125] Trial 137 finished with value: 0.6379191016915124 and parameters: {'learning_rate': 0.14990445936353583, 'max_depth': 6, 'min_child_weight': 7.06765271819161, 'colsample_bytree': 0.3691422672757649, 'subsample': 0.8398498121826957}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:18,545] Trial 138 finished with value: 0.6405643548924036 and parameters: {'learning_rate': 0.0644058553489192, 'max_depth': 6, 'min_child_weight': 4.692634432482113, 'colsample_bytree': 0.9403558675223438, 'subsample': 0.8687622628500434}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:18,835] Trial 139 finished with value: 0.6393142097690919 and parameters: {'learning_rate': 0.16710489224578354, 'max_depth': 5, 'min_child_weight': 5.609859984900685, 'colsample_bytree': 0.33447182774209744, 'subsample': 0.8787145324400008}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:19,186] Trial 140 finished with value: 0.6448311406082927 and parameters: {'learning_rate': 0.06868613314492374, 'max_depth': 5, 'min_child_weight': 5.815002307103294, 'colsample_bytree': 0.5791944146213805, 'subsample': 0.9260750223368418}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:19,516] Trial 141 finished with value: 0.6443725188724448 and parameters: {'learning_rate': 0.06700683353294815, 'max_depth': 5, 'min_child_weight': 5.834875131347507, 'colsample_bytree': 0.5817710045556512, 'subsample': 0.9081079465147812}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:19,831] Trial 142 finished with value: 0.6408241336378838 and parameters: {'learning_rate': 0.07477430315079983, 'max_depth': 5, 'min_child_weight': 5.402367342943882, 'colsample_bytree': 0.6070509443012001, 'subsample': 0.9166552250597116}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:20,163] Trial 143 finished with value: 0.642814487828564 and parameters: {'learning_rate': 0.05468516356509017, 'max_depth': 6, 'min_child_weight': 4.366408581562817, 'colsample_bytree': 0.6293922987689565, 'subsample': 0.9321720569156773}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:20,486] Trial 144 finished with value: 0.6407766678917961 and parameters: {'learning_rate': 0.08434457177738705, 'max_depth': 5, 'min_child_weight': 6.703571994528989, 'colsample_bytree': 0.6533067113294581, 'subsample': 0.9268984596998497}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:20,813] Trial 145 finished with value: 0.6433853596396195 and parameters: {'learning_rate': 0.06971753877400103, 'max_depth': 5, 'min_child_weight': 7.772823384508639, 'colsample_bytree': 0.5694787930919833, 'subsample': 0.8979838134828871}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:21,121] Trial 146 finished with value: 0.6458003398290848 and parameters: {'learning_rate': 0.07871917436520318, 'max_depth': 4, 'min_child_weight': 6.271542050750382, 'colsample_bytree': 0.41431206952452504, 'subsample': 0.8574365178425395}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:21,384] Trial 147 finished with value: 0.643949175731662 and parameters: {'learning_rate': 0.09035858621944562, 'max_depth': 4, 'min_child_weight': 6.285551610674204, 'colsample_bytree': 0.5973855086161811, 'subsample': 0.8582358778106748}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:21,799] Trial 148 finished with value: 0.6468429826705127 and parameters: {'learning_rate': 0.07869838077296283, 'max_depth': 7, 'min_child_weight': 6.439362731469921, 'colsample_bytree': 0.3528114142224476, 'subsample': 0.850727364543152}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:22,175] Trial 149 finished with value: 0.6415726812822679 and parameters: {'learning_rate': 0.08272075391393403, 'max_depth': 7, 'min_child_weight': 6.3877634165429855, 'colsample_bytree': 0.31556854208096424, 'subsample': 0.8477724642990109}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:22,571] Trial 150 finished with value: 0.6420742787611954 and parameters: {'learning_rate': 0.07680948083191341, 'max_depth': 8, 'min_child_weight': 6.523719556777983, 'colsample_bytree': 0.34082813898323844, 'subsample': 0.8336659270131307}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:22,905] Trial 151 finished with value: 0.6342706535327665 and parameters: {'learning_rate': 0.09477626167529149, 'max_depth': 7, 'min_child_weight': 6.0972249755969825, 'colsample_bytree': 0.38025838030137915, 'subsample': 0.8604678279539821}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:23,247] Trial 152 finished with value: 0.6427760020884927 and parameters: {'learning_rate': 0.07683554239316205, 'max_depth': 7, 'min_child_weight': 5.863763181525603, 'colsample_bytree': 0.359822166603924, 'subsample': 0.8752771070587955}. Best is trial 122 with value: 0.6470549749554046.
# [I 2025-02-27 03:29:23,556] Trial 153 finished with value: 0.6421178959332761 and parameters: {'learning_rate': 0.06914103317350062, 'max_depth': 6, 'min_child_weight': 5.682820829117788, 'colsample_bytree': 0.5418264290535234, 'subsample': 0.822770418336842}. Best is trial 122 with value: 0.6470549749554046.
# ...
# [I 2025-02-27 03:33:41,908] Trial 949 finished with value: 0.6414347740470128 and parameters: {'learning_rate': 0.09931199706538762, 'max_depth': 4, 'min_child_weight': 4.963056287977606, 'colsample_bytree': 0.800331048005288, 'subsample': 0.9705553696101173}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:42,201] Trial 950 finished with value: 0.6447006098065514 and parameters: {'learning_rate': 0.10954932364948534, 'max_depth': 4, 'min_child_weight': 6.923926364730003, 'colsample_bytree': 0.574180003668602, 'subsample': 0.9907902259577358}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:42,503] Trial 951 finished with value: 0.6454914917650137 and parameters: {'learning_rate': 0.09357509218947879, 'max_depth': 4, 'min_child_weight': 5.62694760872221, 'colsample_bytree': 0.5944885478254667, 'subsample': 0.9842333032094209}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:42,805] Trial 952 finished with value: 0.642554388368583 and parameters: {'learning_rate': 0.08940609270590448, 'max_depth': 4, 'min_child_weight': 7.918803284010053, 'colsample_bytree': 0.616464784235904, 'subsample': 0.973278125201561}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:43,105] Trial 953 finished with value: 0.6443917617424804 and parameters: {'learning_rate': 0.10210806463418456, 'max_depth': 4, 'min_child_weight': 5.200461553713032, 'colsample_bytree': 0.5787245532947644, 'subsample': 0.9963945121499151}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:43,409] Trial 954 finished with value: 0.6422679903195535 and parameters: {'learning_rate': 0.08664237514328804, 'max_depth': 4, 'min_child_weight': 7.667369373603625, 'colsample_bytree': 0.5620040838522278, 'subsample': 0.9741518835596874}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:43,717] Trial 955 finished with value: 0.642116292360773 and parameters: {'learning_rate': 0.12281887608476452, 'max_depth': 4, 'min_child_weight': 5.817955927723507, 'colsample_bytree': 0.8335410346648602, 'subsample': 0.990697316010687}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:44,003] Trial 956 finished with value: 0.6473615780179716 and parameters: {'learning_rate': 0.1153960481382376, 'max_depth': 4, 'min_child_weight': 5.37800660971493, 'colsample_bytree': 0.5321526175003176, 'subsample': 0.9631604173675018}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:44,295] Trial 957 finished with value: 0.6456688468838416 and parameters: {'learning_rate': 0.118570392613214, 'max_depth': 4, 'min_child_weight': 5.638597818317132, 'colsample_bytree': 0.4982152335930507, 'subsample': 0.9520216261043675}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:44,594] Trial 958 finished with value: 0.6474552266521447 and parameters: {'learning_rate': 0.12641745526198936, 'max_depth': 4, 'min_child_weight': 5.380644137677015, 'colsample_bytree': 0.5236902399511928, 'subsample': 0.962405813132816}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:44,878] Trial 959 finished with value: 0.6434350703872115 and parameters: {'learning_rate': 0.12938525028799178, 'max_depth': 4, 'min_child_weight': 5.345027247094141, 'colsample_bytree': 0.5270904375910662, 'subsample': 0.9597635381260379}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:45,167] Trial 960 finished with value: 0.6427355920614181 and parameters: {'learning_rate': 0.13126422374287905, 'max_depth': 4, 'min_child_weight': 5.454907333240848, 'colsample_bytree': 0.5097540661516793, 'subsample': 0.9671564111078481}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:45,462] Trial 961 finished with value: 0.6448997735114197 and parameters: {'learning_rate': 0.13892213244614204, 'max_depth': 4, 'min_child_weight': 5.46764088073048, 'colsample_bytree': 0.5088556113235684, 'subsample': 0.9632275491165584}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:45,753] Trial 962 finished with value: 0.644511067536701 and parameters: {'learning_rate': 0.12078430573609192, 'max_depth': 4, 'min_child_weight': 7.080376388418726, 'colsample_bytree': 0.5168555277132854, 'subsample': 0.9632041545015743}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:46,040] Trial 963 finished with value: 0.6461313171936969 and parameters: {'learning_rate': 0.11633452341332566, 'max_depth': 4, 'min_child_weight': 5.024613596607923, 'colsample_bytree': 0.4923372746103177, 'subsample': 0.9548653220114233}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:46,340] Trial 964 finished with value: 0.6414347740470129 and parameters: {'learning_rate': 0.13502037181752907, 'max_depth': 4, 'min_child_weight': 5.209061688218739, 'colsample_bytree': 0.4812001100404695, 'subsample': 0.9725037477537092}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:46,658] Trial 965 finished with value: 0.6433359696065282 and parameters: {'learning_rate': 0.12733967010765132, 'max_depth': 4, 'min_child_weight': 6.774748109428873, 'colsample_bytree': 0.5190009914971946, 'subsample': 0.9691857943040245}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:46,950] Trial 966 finished with value: 0.6445441011302621 and parameters: {'learning_rate': 0.127977154046776, 'max_depth': 4, 'min_child_weight': 4.7697936105246646, 'colsample_bytree': 0.5271106929822176, 'subsample': 0.9518214561652097}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:47,251] Trial 967 finished with value: 0.6422404088725024 and parameters: {'learning_rate': 0.13729548841593206, 'max_depth': 4, 'min_child_weight': 7.488889258627304, 'colsample_bytree': 0.5291131833563132, 'subsample': 0.9795288014557386}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:47,581] Trial 968 finished with value: 0.6434722732692802 and parameters: {'learning_rate': 0.12539666311305078, 'max_depth': 4, 'min_child_weight': 5.7234709812527695, 'colsample_bytree': 0.5020811197986836, 'subsample': 0.9844408176120398}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:47,872] Trial 969 finished with value: 0.6450614136197186 and parameters: {'learning_rate': 0.12359537051618415, 'max_depth': 4, 'min_child_weight': 3.237071602162286, 'colsample_bytree': 0.541660320969835, 'subsample': 0.9671552190841962}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:48,193] Trial 970 finished with value: 0.6415983384423154 and parameters: {'learning_rate': 0.11635853717692883, 'max_depth': 4, 'min_child_weight': 5.365507151741735, 'colsample_bytree': 0.5055076755991798, 'subsample': 0.9989467266201789}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:48,489] Trial 971 finished with value: 0.6435534140379303 and parameters: {'learning_rate': 0.1228847851419614, 'max_depth': 4, 'min_child_weight': 5.132342556118287, 'colsample_bytree': 0.5159100644875623, 'subsample': 0.9790441128071026}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:48,783] Trial 972 finished with value: 0.6452964973486532 and parameters: {'learning_rate': 0.1306535746827025, 'max_depth': 4, 'min_child_weight': 7.233858908117569, 'colsample_bytree': 0.5387036313296366, 'subsample': 0.9644609718665093}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:49,079] Trial 973 finished with value: 0.643379586778609 and parameters: {'learning_rate': 0.11379894668568666, 'max_depth': 4, 'min_child_weight': 5.903995670597146, 'colsample_bytree': 0.5312471468157061, 'subsample': 0.953480465288909}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:49,370] Trial 974 finished with value: 0.6453301723712155 and parameters: {'learning_rate': 0.12080570048351641, 'max_depth': 4, 'min_child_weight': 5.495113472756877, 'colsample_bytree': 0.5515314193647283, 'subsample': 0.9456757204610483}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:49,676] Trial 975 finished with value: 0.6405152855738128 and parameters: {'learning_rate': 0.11179539038329818, 'max_depth': 4, 'min_child_weight': 7.816821520368849, 'colsample_bytree': 0.5235408828889921, 'subsample': 0.9872491757797781}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:49,964] Trial 976 finished with value: 0.642107633069257 and parameters: {'learning_rate': 0.115284278406105, 'max_depth': 4, 'min_child_weight': 7.63306041755608, 'colsample_bytree': 0.595881727651253, 'subsample': 0.9748369687158486}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:50,257] Trial 977 finished with value: 0.6428683678646636 and parameters: {'learning_rate': 0.10950749720126401, 'max_depth': 4, 'min_child_weight': 5.001787553195368, 'colsample_bytree': 0.5463104071657572, 'subsample': 0.9997150628902026}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:50,562] Trial 978 finished with value: 0.6460986043146362 and parameters: {'learning_rate': 0.12577858290306398, 'max_depth': 4, 'min_child_weight': 5.634298762949854, 'colsample_bytree': 0.5772959409463289, 'subsample': 0.7635718572356}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:50,859] Trial 979 finished with value: 0.6400332516794215 and parameters: {'learning_rate': 0.1203051657143595, 'max_depth': 4, 'min_child_weight': 5.3077950429643375, 'colsample_bytree': 0.639859409364396, 'subsample': 0.9854223877082162}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:51,156] Trial 980 finished with value: 0.6458407498561596 and parameters: {'learning_rate': 0.10865072675845358, 'max_depth': 4, 'min_child_weight': 6.859792442511836, 'colsample_bytree': 0.5647460801601442, 'subsample': 0.9385165030660201}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:51,447] Trial 981 finished with value: 0.648735518938512 and parameters: {'learning_rate': 0.14129624538183502, 'max_depth': 4, 'min_child_weight': 6.18542482925688, 'colsample_bytree': 0.49459448483002016, 'subsample': 0.9588837908235143}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:51,756] Trial 982 finished with value: 0.6423956346907895 and parameters: {'learning_rate': 0.13864525546124645, 'max_depth': 4, 'min_child_weight': 6.2110639251743756, 'colsample_bytree': 0.5114300424237515, 'subsample': 0.9605235913229088}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:52,053] Trial 983 finished with value: 0.6425130161980066 and parameters: {'learning_rate': 0.1477898402017479, 'max_depth': 4, 'min_child_weight': 6.021025741451341, 'colsample_bytree': 0.5052688407205488, 'subsample': 0.9615015246346456}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:52,360] Trial 984 finished with value: 0.6399819373593265 and parameters: {'learning_rate': 0.11883031537227612, 'max_depth': 4, 'min_child_weight': 6.301883904576692, 'colsample_bytree': 0.4967480379884459, 'subsample': 0.9741889440703817}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:52,653] Trial 985 finished with value: 0.6408748065289775 and parameters: {'learning_rate': 0.14458664066585197, 'max_depth': 4, 'min_child_weight': 6.527051199815434, 'colsample_bytree': 0.47363531605003883, 'subsample': 0.9670072293686902}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:52,946] Trial 986 finished with value: 0.638489973502568 and parameters: {'learning_rate': 0.13402901333963116, 'max_depth': 4, 'min_child_weight': 6.147916043249263, 'colsample_bytree': 0.5121159735080185, 'subsample': 0.9541140990368444}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:53,229] Trial 987 finished with value: 0.641145489567478 and parameters: {'learning_rate': 0.13992103297117606, 'max_depth': 4, 'min_child_weight': 6.333177453204453, 'colsample_bytree': 0.48032195352451157, 'subsample': 0.972567477859243}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:53,521] Trial 988 finished with value: 0.6442487230752159 and parameters: {'learning_rate': 0.1359667087117182, 'max_depth': 4, 'min_child_weight': 5.838207094213939, 'colsample_bytree': 0.48174578243057947, 'subsample': 0.9616506109861717}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:53,843] Trial 989 finished with value: 0.6445822661558327 and parameters: {'learning_rate': 0.12307933009962173, 'max_depth': 4, 'min_child_weight': 6.51531320876569, 'colsample_bytree': 0.4954006821712403, 'subsample': 0.9800240853287772}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:54,138] Trial 990 finished with value: 0.6436130669350406 and parameters: {'learning_rate': 0.12873268911107136, 'max_depth': 4, 'min_child_weight': 6.03831598826479, 'colsample_bytree': 0.48727458421742487, 'subsample': 0.9555875936101725}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:54,434] Trial 991 finished with value: 0.6449340899629832 and parameters: {'learning_rate': 0.13510437067001455, 'max_depth': 4, 'min_child_weight': 6.119357472331411, 'colsample_bytree': 0.4682342497042087, 'subsample': 0.9891393977843264}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:54,735] Trial 992 finished with value: 0.6411984074600758 and parameters: {'learning_rate': 0.14194828374195462, 'max_depth': 4, 'min_child_weight': 5.861241994007648, 'colsample_bytree': 0.5176124396124836, 'subsample': 0.9694136789567769}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:55,030] Trial 993 finished with value: 0.6420704301871882 and parameters: {'learning_rate': 0.13008746867778603, 'max_depth': 4, 'min_child_weight': 6.449219495195148, 'colsample_bytree': 0.4666474310420837, 'subsample': 0.9763874414895801}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:55,330] Trial 994 finished with value: 0.6447952205842263 and parameters: {'learning_rate': 0.12605738539950667, 'max_depth': 4, 'min_child_weight': 6.33055369533171, 'colsample_bytree': 0.4920830372950542, 'subsample': 0.9638639151840158}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:55,643] Trial 995 finished with value: 0.643749049883292 and parameters: {'learning_rate': 0.14508891658994003, 'max_depth': 4, 'min_child_weight': 5.971260933914081, 'colsample_bytree': 0.5028537909594928, 'subsample': 0.9997887941759075}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:55,944] Trial 996 finished with value: 0.6416105255933379 and parameters: {'learning_rate': 0.1400780068268358, 'max_depth': 4, 'min_child_weight': 6.658940489491875, 'colsample_bytree': 0.8074074524615297, 'subsample': 0.9489185130550433}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:56,359] Trial 997 finished with value: 0.6437487291687914 and parameters: {'learning_rate': 0.13046278393997388, 'max_depth': 4, 'min_child_weight': 5.727465635991972, 'colsample_bytree': 0.8530617088452253, 'subsample': 0.9852814985422291}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:56,680] Trial 998 finished with value: 0.640990263749191 and parameters: {'learning_rate': 0.11738836647493224, 'max_depth': 4, 'min_child_weight': 6.143282135913962, 'colsample_bytree': 0.5286318842469134, 'subsample': 0.9708432703137955}. Best is trial 922 with value: 0.6498333246740418.
# [I 2025-02-27 03:33:57,055] Trial 999 finished with value: 0.642919361470258 and parameters: {'learning_rate': 0.13466714537713997, 'max_depth': 4, 'min_child_weight': 5.6268030312147435, 'colsample_bytree': 0.7805188251408988, 'subsample': 0.9557314918028851}. Best is trial 922 with value: 0.6498333246740418.

# %%
# Train the best model
dmatrix_train = xgb.DMatrix(X_train_final, label=y_train, enable_categorical=True)
model = xgb.train(best_params, dmatrix_train, num_boost_round=500)

# %%
# Visualize Optuna Trials
fig = optuna.visualization.matplotlib.plot_optimization_history(study)
plt.savefig("figures/optuna_optimization_history.png")
plt.close()

fig = optuna.visualization.matplotlib.plot_param_importances(study)
plt.savefig("figures/optuna_param_importance.png")
plt.close()
# Out:
# /tmp/ipykernel_2583/737199464.py:2: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   fig = optuna.visualization.matplotlib.plot_optimization_history(study)
# /tmp/ipykernel_2583/737199464.py:6: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   fig = optuna.visualization.matplotlib.plot_param_importances(study)

# %%
explainer = shap.Explainer(model, X_test_final)
shap_values = explainer(X_test_final)

# Save SHAP summary plot
plt.figure()
shap.summary_plot(shap_values, X_test_final, show=False)
plt.savefig("figures/final_shap_summary.png")
plt.close()

# Save SHAP dependence plot for the first feature
plt.figure()
shap.dependence_plot(0, shap_values.values, X_test_final, show=False)
plt.savefig("figures/final_shap_dependence_0.png")
plt.close()
# Out:
#  99%|===================| 2481/2500 [01:05<00:00]

# %%
print("TEST")
acc, roc, precision, recall = eval_model(model, X_test_final, y_test)

print("TRAIN")
acc_train, roc_train, precision_train, recall_train = eval_model(model, X_train_final, y_train)
# Out:
# TEST
# ✅ Test Log Loss: 0.7599
# ✅ Test Accuracy: 0.5912
# ✅ Test AUC: 0.6203
# ✅ Test Precision: 0.5849
# ✅ Test Recall: 0.4887
# TRAIN
# ✅ Test Log Loss: 0.3452
# ✅ Test Accuracy: 0.9200
# ✅ Test AUC: 0.9816
# ✅ Test Precision: 0.9526
# ✅ Test Recall: 0.8725

# %%
# Save the model
model.save_model("models/tuned_xgboost_model.model")
print("Model saved to models/tuned_xgboost_model.model")
# Out:
# Model saved to models/tuned_xgboost_model.model
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [03:35:59] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1738880431132/work/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# ## PUT XGBOOST MODEL IN MODEL STORE

# %%
import tarfile

region = boto3.Session().region_name
role = get_execution_role()
sagemaker_session = sagemaker.Session()

best_params = study.best_params

# ✅ SageMaker client
sm_client = boto3.client("sagemaker", region_name=region)
s3_client = boto3.client("s3", region_name=region)

# ✅ **Model Package Group Name (Unique Identifier)**
model_package_group_name = "xgboost-hospital-readmissions-" + str(int(time.time()))
model_package_group_description = "XGBoost model for predicting hospital readmissions."

# ✅ **Create Model Package Group**
create_model_package_group_response = sm_client.create_model_package_group(
    ModelPackageGroupName=model_package_group_name,
    ModelPackageGroupDescription=model_package_group_description,
)

print("✅ ModelPackageGroup Arn:", create_model_package_group_response["ModelPackageGroupArn"])

# ✅ **Save the trained XGBoost model**
joblib.dump(model, "model.joblib")

# ✅ **Save the model as a compressed `.tar.gz` file**
tar_filename = "model.tar.gz"
with tarfile.open(tar_filename, "w:gz") as tar:
    tar.add("model.joblib")

# ✅ **Upload model to S3**
timestamp = int(time.time())
prefix = "hospital-readmissions-xgboost"
s3_key = f"{prefix}/model-{timestamp}.tar.gz"
model_s3_uri = f"s3://{bucket_name}/{s3_key}"

s3_client.upload_file(tar_filename, bucket_name, s3_key)
print(f"✅ Model artifact uploaded to: {model_s3_uri}")

# ✅ **Define SageMaker Model Package**
model_package_name = "xgboost-hospital-readmissions-package-" + str(int(time.time()))
xgboost_image_uri = "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.5-1"

inference_spec = {
    "Containers": [
        {
            "Image": xgboost_image_uri,
            "ModelDataUrl": model_s3_uri,
        }
    ],
    "SupportedTransformInstanceTypes": ["ml.m5.large", "ml.m5.xlarge"],
    "SupportedRealtimeInferenceInstanceTypes": ["ml.m5.large", "ml.m5.xlarge"],
    "SupportedContentTypes": ["text/csv"],
    "SupportedResponseMIMETypes": ["text/csv", "application/json"],
}

create_model_package_response = sm_client.create_model_package(
    ModelPackageGroupName=model_package_group_name,
    ModelPackageDescription="XGBoost model for predicting hospital readmissions.",
    InferenceSpecification=inference_spec,
    ModelApprovalStatus="PendingManualApproval",
)

print("✅ Model Package ARN:", create_model_package_response["ModelPackageArn"])

# ✅ **Describe the Model Package**
response = sm_client.describe_model_package(
    ModelPackageName=create_model_package_response["ModelPackageArn"]
)

print("Model Package Details:", response)

# ✅ **Create a Model Card**
model_card_name = f"xgboost-hospital-readmissions-card-{int(time.time())}"

# ✅ Update Model Card with **full evaluation details**
model_card_content = {
    "model_overview": {
        "model_description": "XGBoost model predicting hospital readmissions.",
        "model_creator": "Your Team",
        "model_artifact": [model_s3_uri],
        "algorithm_type": "XGBoost",
        "problem_type": "Binary Classification",
        "model_owner": "Group 3",
    },
    "intended_uses": {
        "purpose_of_model": "Predict likelihood of hospital readmission within 30 days.",
        "intended_uses": "Hospital decision support, optimizing patient care.",
        "risk_rating": "Medium",
        "explanations_for_risk_rating": "Incorrect predictions may lead to unnecessary interventions or missed readmissions.",
    },
    "business_details": {
        "business_problem": "Reducing hospital readmission rates.",
        "business_stakeholders": "Healthcare providers, insurers, hospital administrators.",
    },
    "training_details": {
        "training_observations": "Model trained on historical patient admission data.",
        "training_job_details": {
            "training_datasets": [f"sagemaker_featurestore.{latest_table['Name']}"],
            "training_environment": {
                "container_image": [xgboost_image_uri],
            },
            "training_metrics": [
                {"name": "accuracy", "value": acc_train},
                {"name": "roc_auc", "value": roc_train},
                {"name": "precision", "value": precision_train},
                {"name": "recall", "value": recall_train},
            ],
            "hyper_parameters": [
                {"name": k, "value": str(v)} for k, v in best_params.items()
            ],
        },
    },
    "evaluation_details": [
        {
            "name": "evaluation-1",
            "datasets": [f"sagemaker_featurestore.{latest_table['Name']}"],
            "metric_groups": [
                {
                    "name": "readmission-metrics",
                    "metric_data": [
                        {"name": "accuracy", "type": "number", "value": acc},
                        {"name": "roc_auc", "type": "number", "value": roc},
                        {"name": "precision", "type": "number", "value": precision},
                        {"name": "recall", "type": "number", "value": recall},
                    ],
                }
            ],
            "evaluation_observation": "Evaluated on a holdout test dataset.",
        }
    ],
    "additional_information": {
        "ethical_considerations": "Model should not be used to make final medical decisions.",
        "caveats_and_recommendations": "Should be used alongside physician assessment.",
    },
}


# ✅ **Create the Model Card**
response = sm_client.create_model_card(
    ModelCardName=model_card_name,
    Content=json.dumps(model_card_content),
    ModelCardStatus="Draft",
)

print("✅ Model Card ARN:", response["ModelCardArn"])
print("✅ Model Card Name:", model_card_name)

# ✅ **Describe the Model Card**
describe_response = sm_client.describe_model_card(ModelCardName=model_card_name)
print(describe_response)
# Out:
# ✅ ModelPackageGroup Arn: arn:aws:sagemaker:us-east-1:321261761338:model-package-group/xgboost-hospital-readmissions-1740627359
# ✅ Model artifact uploaded to: s3://group3-project-bucket/hospital-readmissions-xgboost/model-1740627360.tar.gz
# ✅ Model Package ARN: arn:aws:sagemaker:us-east-1:321261761338:model-package/xgboost-hospital-readmissions-1740627359/1
# Model Package Details: {'ModelPackageGroupName': 'xgboost-hospital-readmissions-1740627359', 'ModelPackageVersion': 1, 'ModelPackageArn': 'arn:aws:sagemaker:us-east-1:321261761338:model-package/xgboost-hospital-readmissions-1740627359/1', 'ModelPackageDescription': 'XGBoost model for predicting hospital readmissions.', 'CreationTime': datetime.datetime(2025, 2, 27, 3, 36, 1, 326000, tzinfo=tzlocal()), 'InferenceSpecification': {'Containers': [{'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.5-1', 'ImageDigest': 'sha256:c764382b16cd0c921f1b2e66de8684fb999ccbd0c042c95679f0b69bc9cdd12c', 'ModelDataUrl': 's3://group3-project-bucket/hospital-readmissions-xgboost/model-1740627360.tar.gz', 'ModelDataETag': '8340e9dcb67c5412f149b16a38b6375e'}], 'SupportedTransformInstanceTypes': ['ml.m5.large', 'ml.m5.xlarge'], 'SupportedRealtimeInferenceInstanceTypes': ['ml.m5.large', 'ml.m5.xlarge'], 'SupportedContentTypes': ['text/csv'], 'SupportedResponseMIMETypes': ['text/csv', 'application/json']}, 'ModelPackageStatus': 'Completed', 'ModelPackageStatusDetails': {'ValidationStatuses': [], 'ImageScanStatuses': []}, 'CertifyForMarketplace': False, 'ModelApprovalStatus': 'PendingManualApproval', 'CreatedBy': {'UserProfileArn': 'arn:aws:sagemaker:us-east-1:321261761338:user-profile/d-ojigadb1wzup/pfelizarta', 'UserProfileName': 'pfelizarta', 'DomainId': 'd-ojigadb1wzup', 'IamIdentity': {'Arn': 'arn:aws:sts::321261761338:assumed-role/LabRole/SageMaker', 'PrincipalId': 'AROAUVTFROM5FL7RQGG5J:SageMaker'}}, 'ResponseMetadata': {'RequestId': '4b956811-1e56-48b4-8404-3d0cb14d3ff6', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '4b956811-1e56-48b4-8404-3d0cb14d3ff6', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1405', 'date': 'Thu, 27 Feb 2025 03:36:01 GMT'}, 'RetryAttempts': 0}}
# ✅ Model Card ARN: arn:aws:sagemaker:us-east-1:321261761338:model-card/xgboost-hospital-readmissions-card-1740627361
# ✅ Model Card Name: xgboost-hospital-readmissions-card-1740627361
# {'ModelCardArn': 'arn:aws:sagemaker:us-east-1:321261761338:model-card/xgboost-hospital-readmissions-card-1740627361', 'ModelCardName': 'xgboost-hospital-readmissions-card-1740627361', 'ModelCardVersion': 1, 'Content': '{"model_overview": {"model_description": "XGBoost model predicting hospital readmissions.", "model_creator": "Your Team", "model_artifact": ["s3://group3-project-bucket/hospital-readmissions-xgboost/model-1740627360.tar.gz"], "algorithm_type": "XGBoost", "problem_type": "Binary Classification", "model_owner": "Group 3"}, "intended_uses": {"purpose_of_model": "Predict likelihood of hospital readmission within 30 days.", "intended_uses": "Hospital decision support, optimizing patient care.", "risk_rating": "Medium", "explanations_for_risk_rating": "Incorrect predictions may lead to unnecessary interventions or missed readmissions."}, "business_details": {"business_problem": "Reducing hospital readmission rates.", "business_stakeholders": "Healthcare providers, insurers, hospital administrators."}, "training_details": {"training_observations": "Model trained on historical patient admission data.", "training_job_details": {"training_datasets": ["sagemaker_featurestore.hospital_readmissions_features_1740354579"], "training_environment": {"container_image": ["683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.5-1"]}, "training_metrics": [{"name": "accuracy", "value": 0.92}, {"name": "roc_auc", "value": 0.9816101091111729}, {"name": "precision", "value": 0.9525854022773941}, {"name": "recall", "value": 0.8724568302273893}], "hyper_parameters": [{"name": "learning_rate", "value": "0.08806086821951509"}, {"name": "max_depth", "value": "6"}, {"name": "min_child_weight", "value": "4.91379613345548"}, {"name": "colsample_bytree", "value": "0.5820894074144078"}, {"name": "subsample", "value": "0.7956944347696608"}]}}, "evaluation_details": [{"name": "evaluation-1", "datasets": ["sagemaker_featurestore.hospital_readmissions_features_1740354579"], "metric_groups": [{"name": "readmission-metrics", "metric_data": [{"name": "accuracy", "type": "number", "value": 0.5912}, {"name": "roc_auc", "type": "number", "value": 0.6202875013069116}, {"name": "precision", "type": "number", "value": 0.5849246231155779}, {"name": "recall", "type": "number", "value": 0.48866498740554154}]}], "evaluation_observation": "Evaluated on a holdout test dataset."}], "additional_information": {"ethical_considerations": "Model should not be used to make final medical decisions.", "caveats_and_recommendations": "Should be used alongside physician assessment."}}', 'ModelCardStatus': 'Draft', 'CreationTime': datetime.datetime(2025, 2, 27, 3, 36, 1, 645000, tzinfo=tzlocal()), 'CreatedBy': {'UserProfileArn': 'arn:aws:sagemaker:us-east-1:321261761338:user-profile/d-ojigadb1wzup/pfelizarta', 'UserProfileName': 'pfelizarta', 'DomainId': 'd-ojigadb1wzup'}, 'LastModifiedTime': datetime.datetime(2025, 2, 27, 3, 36, 1, 645000, tzinfo=tzlocal()), 'LastModifiedBy': {'UserProfileArn': 'arn:aws:sagemaker:us-east-1:321261761338:user-profile/d-ojigadb1wzup/pfelizarta', 'UserProfileName': 'pfelizarta', 'DomainId': 'd-ojigadb1wzup'}, 'ResponseMetadata': {'RequestId': 'e3648cff-9fce-4d02-ae93-2730cc22f24b', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'e3648cff-9fce-4d02-ae93-2730cc22f24b', 'content-type': 'application/x-amz-json-1.1', 'content-length': '3241', 'date': 'Thu, 27 Feb 2025 03:36:02 GMT'}, 'RetryAttempts': 0}}
